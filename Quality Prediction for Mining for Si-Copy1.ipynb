# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('DATA/MiningProcess_Flotation_Plant_Database.csv',decimal=',').drop_duplicates()
df.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1  2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2  2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3  2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4  2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
#    Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# 0                       253.235  ...                       250.884
# 1                       250.532  ...                       248.994
# 2                       247.874  ...                       248.071
# 3                       254.487  ...                       251.147
# 4                       252.136  ...                       248.928
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    457.396                    432.962
# 1                    451.891                    429.560
# 2                    451.240                    468.927
# 3                    452.441                    458.165
# 4                    452.441                    452.900
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    424.954                    443.558
# 1                    432.939                    448.086
# 2                    434.610                    449.688
# 3                    442.865                    446.210
# 4                    450.523                    453.670
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                    502.255                    446.370
# 1                    496.363                    445.922
# 2                    484.411                    447.826
# 3                    471.411                    437.690
# 4                    462.598                    443.682
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                    523.344               66.91                  1.31
# 1                    498.075               66.91                  1.31
# 2                    458.567               66.91                  1.31
# 3                    427.669               66.91                  1.31
# 4                    425.679               66.91                  1.31
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (736282, 24)

# %%
df.columns
# Out:
# Index(['date', '% Iron Feed', '% Silica Feed', 'Starch Flow', 'Amina Flow',
#        'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density',
#        'Flotation Column 01 Air Flow', 'Flotation Column 02 Air Flow',
#        'Flotation Column 03 Air Flow', 'Flotation Column 04 Air Flow',
#        'Flotation Column 05 Air Flow', 'Flotation Column 06 Air Flow',
#        'Flotation Column 07 Air Flow', 'Flotation Column 01 Level',
#        'Flotation Column 02 Level', 'Flotation Column 03 Level',
#        'Flotation Column 04 Level', 'Flotation Column 05 Level',
#        'Flotation Column 06 Level', 'Flotation Column 07 Level',
#        '% Iron Concentrate', '% Silica Concentrate'],
#       dtype='object')

# %% [markdown]
# # Date in Mining Ores

# %%
df=df.groupby(['date']).mean()

# %%
plt.figure(figsize=(30,10))
df.groupby(['date']).mean()['% Silica Concentrate'].plot()
plt.show()

# %%
plt.figure(figsize=(30,10))
df.groupby(['date']).mean()['% Iron Concentrate'].plot()
plt.show()

# %%
df.groupby(['% Silica Concentrate']).mean()
# Out:
#                       % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# % Silica Concentrate
# 0.600000                    48.81          25.31  3507.572389  430.847311
# 0.660000                    48.81          25.31  2185.361279  419.244482
# 0.740000                    48.81          25.31  3890.823333  458.506367
# 0.750000                    48.81          25.31  2975.124778  393.377690
# 0.770000                    56.45          13.57  2169.709250  505.566494
# ...                           ...            ...          ...         ...
# 5.500000                    52.97          19.24  2640.554836  449.989819
# 5.510000                    56.65          14.83  3306.428806  560.858150
# 5.511599                    57.46          10.80  4460.684444  585.196306
# 5.520000                    48.81          25.31  3637.766532  490.466856
# 5.530000                    49.80          22.34  3414.716557  584.756947
#
#                       Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# % Silica Concentrate
# 0.600000                 379.343667    10.291061          1.700894
# 0.660000                 381.502420     9.469579          1.684721
# 0.740000                 381.110714    10.395589          1.687037
# 0.750000                 381.802851    10.032917          1.691862
# 0.770000                 399.946089     9.599748          1.740165
# ...                             ...          ...               ...
# 5.500000                 400.585803     9.959624          1.628695
# 5.510000                 399.863361     9.714392          1.767121
# 5.511599                 400.017889    10.315017          1.706781
# 5.520000                 379.253965     9.458973          1.679028
# 5.530000                 400.118455     9.819079          1.707561
#
#                       Flotation Column 01 Air Flow  \
# % Silica Concentrate
# 0.600000                                299.788706
# 0.660000                                299.946906
# 0.740000                                299.857589
# 0.750000                                299.739750
# 0.770000                                250.016756
# ...                                            ...
# 5.500000                                249.876039
# 5.510000                                250.079806
# 5.511599                                299.912117
# 5.520000                                299.905733
# 5.530000                                299.795376
#
#                       Flotation Column 02 Air Flow  \
# % Silica Concentrate
# 0.600000                                249.868783
# 0.660000                                300.510120
# 0.740000                                249.901839
# 0.750000                                250.036283
# 0.770000                                249.942567
# ...                                            ...
# 5.500000                                247.947896
# 5.510000                                249.494772
# 5.511599                                299.367744
# 5.520000                                300.000778
# 5.530000                                299.886991
#
#                       Flotation Column 03 Air Flow  ...  \
# % Silica Concentrate                                ...
# 0.600000                                299.859722  ...
# 0.660000                                299.952711  ...
# 0.740000                                299.920178  ...
# 0.750000                                299.923211  ...
# 0.770000                                250.024272  ...
# ...                                            ...  ...
# 5.500000                                249.918008  ...
# 5.510000                                250.182622  ...
# 5.511599                                299.900856  ...
# 5.520000                                299.948800  ...
# 5.530000                                299.883157  ...
#
#                       Flotation Column 06 Air Flow  \
# % Silica Concentrate
# 0.600000                                299.580378
# 0.660000                                249.966511
# 0.740000                                299.991356
# 0.750000                                299.779978
# 0.770000                                250.022533
# ...                                            ...
# 5.500000                                275.008383
# 5.510000                                300.338256
# 5.511599                                299.842428
# 5.520000                                349.595886
# 5.530000                                299.776535
#
#                       Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# % Silica Concentrate
# 0.600000                                287.760011                 549.482956
# 0.660000                                250.045646                 553.295064
# 0.740000                                299.922417                 550.379206
# 0.750000                                250.008144                 556.294867
# 0.770000                                250.085961                 603.269472
# ...                                            ...                        ...
# 5.500000                                274.915122                 653.833991
# 5.510000                                300.022756                 451.315256
# 5.511599                                299.878472                 400.162356
# 5.520000                                349.945217                 837.866625
# 5.530000                                299.626998                 466.203320
#
#                       Flotation Column 02 Level  Flotation Column 03 Level  \
# % Silica Concentrate
# 0.600000                             548.923283                 549.972750
# 0.660000                             504.124909                 750.439797
# 0.740000                             549.588667                 549.821300
# 0.750000                             553.436206                 560.644808
# 0.770000                             600.161144                 601.072817
# ...                                         ...                        ...
# 5.500000                             617.233895                 642.491621
# 5.510000                             449.732978                 449.917794
# 5.511599                             400.333917                 400.035650
# 5.520000                             500.528383                 599.677861
# 5.530000                             470.200318                 543.103345
#
#                       Flotation Column 04 Level  Flotation Column 05 Level  \
# % Silica Concentrate
# 0.600000                             516.092072                 517.980733
# 0.660000                             454.544115                 453.474052
# 0.740000                             498.237644                 499.867883
# 0.750000                             562.173389                 550.175139
# 0.770000                             449.567033                 449.980850
# ...                                         ...                        ...
# 5.500000                             401.359208                 401.800444
# 5.510000                             351.711089                 350.358672
# 5.511599                             350.805544                 349.401067
# 5.520000                             403.173205                 346.573111
# 5.530000                             397.303592                 400.015793
#
#                       Flotation Column 06 Level  Flotation Column 07 Level  \
# % Silica Concentrate
# 0.600000                             511.288872                 513.563067
# 0.660000                             500.682550                 502.348081
# 0.740000                             499.730194                 498.209325
# 0.750000                             552.597044                 551.615594
# 0.770000                             447.103056                 450.250956
# ...                                         ...                        ...
# 5.500000                             413.554439                 400.169994
# 5.510000                             350.592067                 350.840683
# 5.511599                             357.413306                 350.789650
# 5.520000                             352.913850                 345.176044
# 5.530000                             401.980517                 399.966089
#
#                       % Iron Concentrate
# % Silica Concentrate
# 0.600000                       66.570000
# 0.660000                       65.120000
# 0.740000                       65.610000
# 0.750000                       66.780000
# 0.770000                       66.900000
# ...                                  ...
# 5.500000                       63.245000
# 5.510000                       63.430000
# 5.511599                       62.360000
# 5.520000                       63.066512
# 5.530000                       63.658947
#
# [762 rows x 22 columns]

# %%
df.groupby(['% Iron Concentrate']).mean()
# Out:
#                     % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# % Iron Concentrate
# 62.05000              57.080000      13.350000  2234.233667  542.608150
# 62.11000              48.050000      28.540000  2100.065060  507.606972
# 62.11904              48.050000      28.540000  3485.501755  571.682100
# 62.12000              52.610000      20.240000  3683.954139  346.926800
# 62.13000              54.396667      16.763333  2132.004176  483.139056
# ...                         ...            ...          ...         ...
# 67.63000              64.030000       6.260000  4052.176444  450.924417
# 67.66000              49.350000      24.900000  3077.049500  377.148094
# 67.67000              48.810000      25.310000  3641.604167  404.219844
# 67.99000              55.780000      12.850000  2588.626106  431.233456
# 68.01000              47.790000      27.080000  4322.071578  517.330928
#
#                     Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# % Iron Concentrate
# 62.05000               400.167157     9.764361          1.766480
# 62.11000               380.441201     9.193370          1.704116
# 62.11904               381.947644     9.326836          1.736099
# 62.12000               400.364806     9.946232          1.531673
# 62.13000               395.043856     9.480989          1.656493
# ...                           ...          ...               ...
# 67.63000               400.162194    10.158235          1.594675
# 67.66000               400.064061    10.244143          1.658189
# 67.67000               380.739842     9.933260          1.704377
# 67.99000               400.952456    10.693607          1.543400
# 68.01000               399.700861    10.463737          1.732864
#
#                     Flotation Column 01 Air Flow  \
# % Iron Concentrate
# 62.05000                              275.036800
# 62.11000                              299.850017
# 62.11904                              299.996867
# 62.12000                              249.949344
# 62.13000                              283.365220
# ...                                          ...
# 67.63000                              299.930939
# 67.66000                              249.998239
# 67.67000                              299.911356
# 67.99000                              299.981528
# 68.01000                              299.859072
#
#                     Flotation Column 02 Air Flow  \
# % Iron Concentrate
# 62.05000                              275.150456
# 62.11000                              299.600144
# 62.11904                              299.463700
# 62.12000                              249.805889
# 62.13000                              283.389937
# ...                                          ...
# 67.63000                              299.651872
# 67.66000                              249.948056
# 67.67000                              298.836394
# 67.99000                              300.051550
# 68.01000                              299.737372
#
#                     Flotation Column 03 Air Flow  ...  \
# % Iron Concentrate                                ...
# 62.05000                              274.954469  ...
# 62.11000                              299.864300  ...
# 62.11904                              299.931089  ...
# 62.12000                              250.040244  ...
# 62.13000                              283.270239  ...
# ...                                          ...  ...
# 67.63000                              299.908261  ...
# 67.66000                              250.111900  ...
# 67.67000                              299.982222  ...
# 67.99000                              299.870878  ...
# 68.01000                              299.957161  ...
#
#                     Flotation Column 06 Air Flow  \
# % Iron Concentrate
# 62.05000                              274.577364
# 62.11000                              349.316864
# 62.11904                              350.054000
# 62.12000                              300.002106
# 62.13000                              300.082676
# ...                                          ...
# 67.63000                              299.995489
# 67.66000                              299.998294
# 67.67000                              349.317211
# 67.99000                              299.905022
# 68.01000                              300.061800
#
#                     Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# % Iron Concentrate
# 62.05000                              275.109861                 569.033331
# 62.11000                              305.914508                 399.751889
# 62.11904                              311.111102                 399.383250
# 62.12000                              299.920772                 450.150000
# 62.13000                              300.085665                 484.667046
# ...                                          ...                        ...
# 67.63000                              299.936183                 500.537472
# 67.66000                              300.866928                 600.451433
# 67.67000                              349.772067                 500.660422
# 67.99000                              299.571333                 400.753367
# 68.01000                              299.814578                 500.424794
#
#                     Flotation Column 02 Level  Flotation Column 03 Level  \
# % Iron Concentrate
# 62.05000                           647.687120                 877.901875
# 62.11000                           600.531183                 399.436383
# 62.11904                           599.842083                 399.772933
# 62.12000                           449.762178                 449.756683
# 62.13000                           516.510041                 504.376794
# ...                                       ...                        ...
# 67.63000                           488.634144                 517.281154
# 67.66000                           599.180372                 600.377139
# 67.67000                           498.751794                 499.952850
# 67.99000                           397.946039                 399.183533
# 68.01000                           499.444217                 499.406578
#
#                     Flotation Column 04 Level  Flotation Column 05 Level  \
# % Iron Concentrate
# 62.05000                           374.896306                 372.729694
# 62.11000                           351.845639                 352.289911
# 62.11904                           349.469867                 348.804994
# 62.12000                           347.386717                 348.333950
# 62.13000                           367.045839                 365.601954
# ...                                       ...                        ...
# 67.63000                           497.519506                 497.175128
# 67.66000                           500.624361                 499.948867
# 67.67000                           353.228433                 350.180106
# 67.99000                           411.818111                 401.818483
# 68.01000                           499.020506                 499.049967
#
#                     Flotation Column 06 Level  Flotation Column 07 Level  \
# % Iron Concentrate
# 62.05000                           392.507081                 371.004833
# 62.11000                           364.596606                 352.851806
# 62.11904                           351.553300                 349.404322
# 62.12000                           350.529944                 347.707206
# 62.13000                           368.431615                 366.682936
# ...                                       ...                        ...
# 67.63000                           503.977833                 499.653206
# 67.66000                           449.454133                 448.839872
# 67.67000                           354.699483                 353.110700
# 67.99000                           398.992378                 405.573106
# 68.01000                           501.710136                 497.050772
#
#                     % Silica Concentrate
# % Iron Concentrate
# 62.05000                        4.100062
# 62.11000                        4.568052
# 62.11904                        4.626558
# 62.12000                        3.365000
# 62.13000                        4.687359
# ...                                  ...
# 67.63000                        1.050000
# 67.66000                        1.410000
# 67.67000                        1.030000
# 67.99000                        1.100000
# 68.01000                        1.380000
#
# [738 rows x 22 columns]

# %% [markdown]
# Since dataset is very huge .Considering to split the data into train and test

# %% [markdown]
# ## % for Silicon Concentration

# %%
# Deleting date columns and % Iron Concentration
y=df['% Silica Concentrate']
X=df.drop(['% Silica Concentrate','% Iron Concentrate'],axis=1)

# %% [markdown]
# ## 1. Base Model

# %%
import statsmodels.api as sm
xc=sm.add_constant(X)
xc=xc.drop(['Flotation Column 07 Air Flow'],axis=1)
model=sm.OLS(y,xc).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     % Silica Concentrate   R-squared:                       0.170
# Model:                              OLS   Adj. R-squared:                  0.166
# Method:                   Least Squares   F-statistic:                     41.87
# Date:                  Sat, 23 May 2020   Prob (F-statistic):          8.52e-149
# Time:                          12:59:27   Log-Likelihood:                -5911.9
# No. Observations:                  4097   AIC:                         1.187e+04
# Df Residuals:                      4076   BIC:                         1.200e+04
# Df Model:                            20
# Covariance Type:              nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                            3.6030      3.654      0.986      0.324      -3.560      10.766
# % Iron Feed                      0.0003      0.014      0.019      0.985      -0.027       0.027
# % Silica Feed                    0.0084      0.010      0.811      0.417      -0.012       0.029
# Starch Flow                  -8.324e-05   2.15e-05     -3.877      0.000      -0.000   -4.12e-05
# Amina Flow                       0.0041      0.000     13.999      0.000       0.004       0.005
# Ore Pulp Flow                   -0.0074      0.002     -3.283      0.001      -0.012      -0.003
# Ore Pulp pH                     -0.2973      0.048     -6.162      0.000      -0.392      -0.203
# Ore Pulp Density                -2.3415      0.369     -6.348      0.000      -3.065      -1.618
# Flotation Column 01 Air Flow    -0.0093      0.002     -4.556      0.000      -0.013      -0.005
# Flotation Column 02 Air Flow     0.0013      0.001      1.037      0.300      -0.001       0.004
# Flotation Column 03 Air Flow    -0.0058      0.002     -2.539      0.011      -0.010      -0.001
# Flotation Column 04 Air Flow     0.0409      0.009      4.668      0.000       0.024       0.058
# Flotation Column 05 Air Flow    -0.0056      0.006     -1.015      0.310      -0.017       0.005
# Flotation Column 06 Air Flow     0.0027      0.001      3.241      0.001       0.001       0.004
# Flotation Column 01 Level       -0.0001      0.000     -0.508      0.611      -0.001       0.000
# Flotation Column 02 Level       -0.0002      0.000     -0.962      0.336      -0.001       0.000
# Flotation Column 03 Level        0.0002      0.000      0.881      0.379      -0.000       0.001
# Flotation Column 04 Level       -0.0005      0.000     -1.230      0.219      -0.001       0.000
# Flotation Column 05 Level       -0.0017      0.000     -3.897      0.000      -0.003      -0.001
# Flotation Column 06 Level        0.0007      0.000      1.934      0.053   -9.36e-06       0.001
# Flotation Column 07 Level       -0.0003      0.000     -0.671      0.502      -0.001       0.001
# ==============================================================================
# Omnibus:                      401.285   Durbin-Watson:                   0.572
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              525.847
# Skew:                           0.866   Prob(JB):                    6.51e-115
# Kurtosis:                       3.289   Cond. No.                     7.68e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.68e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
residuals=model.resid
sns.distplot(residuals)

# %%
import scipy.stats as stats
stats.probplot(residuals,plot=plt)
plt.show()

# %% [markdown]
# ### Autocorrelation Check

# %%
import statsmodels.tsa.api as smt
acf=smt.graphics.plot_acf(residuals,lags=40)
acf.show()
# Out:
# C:\Users\pravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Multicollinearity Check

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
pd.DataFrame({'vif':vif},index=X.columns).T
# Out:
#      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  Ore Pulp Flow  \
# vif  2228.083815     103.410492    16.279953   80.742324     3002.77585
#
#      Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# vif     876.6513       1409.160807                   1284.281141
#
#      Flotation Column 02 Air Flow  Flotation Column 03 Air Flow  ...  \
# vif                    458.315662                   1615.956066  ...
#
#      Flotation Column 05 Air Flow  Flotation Column 06 Air Flow  \
# vif                   7313.185064                     671.89709
#
#      Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# vif                    810.615798                  79.823816
#
#      Flotation Column 02 Level  Flotation Column 03 Level  \
# vif                  68.505798                  49.557277
#
#      Flotation Column 04 Level  Flotation Column 05 Level  \
# vif                  99.068872                 146.401985
#
#      Flotation Column 06 Level  Flotation Column 07 Level
# vif                  91.329361                 150.271758
#
# [1 rows x 21 columns]

# %%
from sklearn import metrics

# %% [markdown]
# ### 2.Linear Regression -ML

# %%
y=df['% Silica Concentrate']
X=df.drop(['% Silica Concentrate','% Iron Concentrate'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                        test_size=0.30, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train_pred=lr.predict(X_train)
print ("feature_importances:",lr.intercept_)
print ("n_coefficients:         ",lr.coef_)
# Out:
# feature_importances: 4.303044308596033
# n_coefficients:          [-3.50373309e-03  5.94827442e-03 -8.08744255e-05  4.60382515e-03
#  -7.52524273e-03 -3.08567374e-01 -2.76853485e+00 -1.04320745e-02
#   1.10317604e-03 -4.63776931e-03  4.21824412e-02 -6.80023149e-03
#   2.88381707e-03  1.52028246e-04  5.34936911e-05 -2.30487724e-04
#   1.74642251e-04 -1.56249147e-04 -1.86743809e-03  2.73269957e-04
#  -8.56573781e-05]

# %%
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.18031178648170088
# L1 Mean absolute Error:  0.8073647316178666
# L2 Mean square Error:  1.0385997098982798
# L2 RMSE:  1.0191171227578701

# %%
y_test_pred=lr.predict(X_test)

# %%
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.14219582447742052
# L1 Mean absolute Error:  0.8160958726244152
# L2 Mean square Error:  1.080498294943362
# L2 RMSE:  1.0394701991607849

# %% [markdown]
# ## 3. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### Changing max depth

# %%
train_accuracy=[]
test_accuracy=[]

for depth in range(5,20):
    dt_model=DecisionTreeRegressor(max_depth=depth,random_state=42)
    dt_model.fit(X_train,y_train)
    train_accuracy.append(dt_model.score(X_train,y_train))
    test_accuracy.append(dt_model.score(X_test,y_test))

# %%
frame=pd.DataFrame({'max_depth':range(5,20),'train_accuracy':train_accuracy,'test_accuracy':test_accuracy})
print(frame)
# Out:
#     max_depth  train_accuracy  test_accuracy
# 0           5        0.286526       0.155965
# 1           6        0.348549       0.151862
# 2           7        0.420046       0.133226
# 3           8        0.499691       0.073335
# 4           9        0.580026       0.040529
# 5          10        0.658744       0.022265
# 6          11        0.735676      -0.048696
# 7          12        0.795068      -0.050782
# 8          13        0.852150      -0.128122
# 9          14        0.901364      -0.131898
# 10         15        0.935721      -0.205126
# 11         16        0.960644      -0.258006
# 12         17        0.976154      -0.301900
# 13         18        0.985604      -0.298182
# 14         19        0.992418      -0.297262

# %%
plt.figure(figsize=(13,6))
plt.plot(frame['max_depth'],frame['train_accuracy'],marker='o')
plt.plot(frame['max_depth'],frame['test_accuracy'],marker='o')
plt.xlabel('Depth of Tree')
plt.ylabel('Accuracy Performance')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
print ("feature_importances:",dtr.feature_importances_)
print ("Best params: \n        ",dtr.get_params)
print('n feature',dtr.n_features_)
print(dtr.n_outputs_)
# Out:
# feature_importances: [0.02924659 0.02891822 0.04760108 0.08160346 0.04931553 0.07351221
#  0.08281061 0.04875211 0.02063217 0.1103148  0.07472271 0.02093365
#  0.03742344 0.02728896 0.03055937 0.03758208 0.03793575 0.03438311
#  0.03891091 0.05148964 0.03606359]
# Best params:
#          <bound method BaseEstimator.get_params of DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')>
# n feature 21
# 1

# %%
y_train_pred=dtr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.9995784792827259
# L1 Mean absolute Error:  0.0006105329272859755
# L2 Mean square Error:  0.0005340949003010852
# L2 RMSE:  0.02311049329419615

# %%
y_test_pred=dtr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  -0.3008330146705571
# L1 Mean absolute Error:  0.9171525913738591
# L2 Mean square Error:  1.6385416327698594
# L2 RMSE:  1.2800553241051182

# %% [markdown]
# ## 4. Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
print ("feature_importances:",rfr.feature_importances_)
print ("n_coefficients:         ",rfr.get_params)
print('n feature',rfr.n_features_)
print(rfr.n_outputs_)
# Out:
# feature_importances: [0.02917034 0.03962937 0.04913108 0.1052449  0.04785141 0.05417462
#  0.05232698 0.07518114 0.0342065  0.0630753  0.05924787 0.03325041
#  0.03518724 0.03344367 0.03875879 0.04048013 0.04114861 0.04463059
#  0.04302847 0.04203843 0.03879416]
# n_coefficients:          <bound method BaseEstimator.get_params of RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)>
# n feature 21
# 1

# %%
y_train_pred=rfr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.903764039302769
# L1 Mean absolute Error:  0.26918684182046826
# L2 Mean square Error:  0.12193738937993764
# L2 RMSE:  0.3491953455874486

# %%
y_test_pred=rfr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.30744751836952033
# L1 Mean absolute Error:  0.7256524615533276
# L2 Mean square Error:  0.8723456902091404
# L2 RMSE:  0.9339944808237041

# %% [markdown]
# ## Gradient Boosting

# %%
params = {
    'n_estimators': 80,
    'max_depth': 12,
    'learning_rate': 0.1,
    'criterion': 'mse'
    }

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(**params)

# %%
gbr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=12,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=80,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_train_pred=gbr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.9992810005881396
# L1 Mean absolute Error:  0.015329673771825491
# L2 Mean square Error:  0.000911020273635454
# L2 RMSE:  0.030183112391459137

# %%
y_test_pred=gbr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.2710899413447162
# L1 Mean absolute Error:  0.7169108468459757
# L2 Mean square Error:  0.9181420398942427
# L2 RMSE:  0.9581972865199748

# %% [markdown]
# ## Dimensionaly Reduction with PCA n=15

# %%
from sklearn.decomposition import PCA

# %%
# Dimensions reduction with Principal Components Analysis
pca = PCA(n_components=15)
pca.fit(X)
X_pca = pca.fit_transform(X)

# Creation of the different datasets for training and testing
X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(X_pca, y, test_size=0.8, random_state=42)

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(**params)

# %%
gbr.fit(X_train_pca,y_train_pca)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=12,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=80,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_train_pred=gbr.predict(X_train_pca)
print('R2 of Train: ', metrics.r2_score(y_train_pca,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train_pca,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train_pca,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train_pca,y_train_pred)))
# Out:
# R2 of Train:  0.9999994221353621
# L1 Mean absolute Error:  0.000694379655514393
# L2 Mean square Error:  8.022800378814488e-07
# L2 RMSE:  0.0008957008640620198

# %%
y_test_pred=gbr.predict(X_test_pca)
print('R2 of Test: ', metrics.r2_score(y_test_pca,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test_pca,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test_pca,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test_pca,y_test_pred)))
# Out:
# R2 of Test:  -0.08788629207148091
# L1 Mean absolute Error:  0.8683325920145262
# L2 Mean square Error:  1.342162363783362
# L2 RMSE:  1.1585173126817578

# %% [markdown]
# ### Random Forest Regressor

# %%
rfr_pca=RandomForestRegressor()

# %%
rfr_pca.fit(X_train_pca,y_train_pca)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
print ("feature_importances:",rfr_pca.feature_importances_)
print ("n_coefficients:         ",rfr_pca.get_params)
print('n feature',rfr_pca.n_features_)
print(rfr_pca.n_outputs_)
# Out:
# feature_importances: [0.09384355 0.06016003 0.09817994 0.10823194 0.04719984 0.05502178
#  0.06787628 0.04940603 0.05273992 0.04754771 0.07692443 0.05567562
#  0.05750068 0.04807607 0.08161618]
# n_coefficients:          <bound method BaseEstimator.get_params of RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)>
# n feature 15
# 1

# %%
y_train_pred=rfr_pca.predict(X_train_pca)
print('R2 of Train: ', metrics.r2_score(y_train_pca,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train_pca,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train_pca,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train_pca,y_train_pred)))
# Out:
# R2 of Train:  0.8879792211329216
# L1 Mean absolute Error:  0.3092583663677329
# L2 Mean square Error:  0.15552437165893368
# L2 RMSE:  0.394365784087481

# %%
y_test_pred=rfr_pca.predict(X_test_pca)
print('R2 of Test: ', metrics.r2_score(y_test_pca,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test_pca,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test_pca,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test_pca,y_test_pred)))
# Out:
# R2 of Test:  0.19526860306518445
# L1 Mean absolute Error:  0.7851730360095046
# L2 Mean square Error:  0.9928245275194175
# L2 RMSE:  0.9964058046395643

# %%
del X_train_pca, X_test_pca, y_train_pca, y_test_pca,rfr_pca,gbr
