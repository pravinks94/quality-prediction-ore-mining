# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('../DATA/MiningProcess_Flotation_Plant_Database.csv',decimal=',').drop_duplicates()
df.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1  2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2  2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3  2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4  2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
#    Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# 0                       253.235  ...                       250.884
# 1                       250.532  ...                       248.994
# 2                       247.874  ...                       248.071
# 3                       254.487  ...                       251.147
# 4                       252.136  ...                       248.928
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    457.396                    432.962
# 1                    451.891                    429.560
# 2                    451.240                    468.927
# 3                    452.441                    458.165
# 4                    452.441                    452.900
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    424.954                    443.558
# 1                    432.939                    448.086
# 2                    434.610                    449.688
# 3                    442.865                    446.210
# 4                    450.523                    453.670
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                    502.255                    446.370
# 1                    496.363                    445.922
# 2                    484.411                    447.826
# 3                    471.411                    437.690
# 4                    462.598                    443.682
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                    523.344               66.91                  1.31
# 1                    498.075               66.91                  1.31
# 2                    458.567               66.91                  1.31
# 3                    427.669               66.91                  1.31
# 4                    425.679               66.91                  1.31
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (736282, 24)

# %%
df.columns
# Out:
# Index(['date', '% Iron Feed', '% Silica Feed', 'Starch Flow', 'Amina Flow',
#        'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density',
#        'Flotation Column 01 Air Flow', 'Flotation Column 02 Air Flow',
#        'Flotation Column 03 Air Flow', 'Flotation Column 04 Air Flow',
#        'Flotation Column 05 Air Flow', 'Flotation Column 06 Air Flow',
#        'Flotation Column 07 Air Flow', 'Flotation Column 01 Level',
#        'Flotation Column 02 Level', 'Flotation Column 03 Level',
#        'Flotation Column 04 Level', 'Flotation Column 05 Level',
#        'Flotation Column 06 Level', 'Flotation Column 07 Level',
#        '% Iron Concentrate', '% Silica Concentrate'],
#       dtype='object')

# %% [markdown]
# # Date in Mining Ores

# %%
df.groupby(['date'])

# %%
plt.figure(figsize=(30,10))
df.groupby(['date']).mean()['% Silica Concentrate'].plot()
plt.show()

# %%
plt.figure(figsize=(30,10))
df.groupby(['date']).mean()['% Iron Concentrate'].plot()
plt.show()

# %%
df.groupby(['% Silica Concentrate']).mean()
# Out:
#                       % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# % Silica Concentrate
# 0.600000                    48.81          25.31  3507.572389  430.847311
# 0.660000                    48.81          25.31  2185.361279  419.244482
# 0.740000                    48.81          25.31  3890.823333  458.506367
# 0.750000                    48.81          25.31  2975.124778  393.377690
# 0.770000                    56.45          13.57  2169.709250  505.566494
# ...                           ...            ...          ...         ...
# 5.529187                    57.46          10.80  4851.520000  656.820000
# 5.529390                    57.46          10.80  4836.140000  624.736000
# 5.529593                    57.46          10.80  4824.430000  642.565000
# 5.529797                    57.46          10.80  4801.680000  637.808000
# 5.530000                    49.80          22.34  3414.716557  584.756947
#
#                       Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# % Silica Concentrate
# 0.600000                 379.343667    10.291061          1.700894
# 0.660000                 381.502420     9.469579          1.684721
# 0.740000                 381.110714    10.395589          1.687037
# 0.750000                 381.802851    10.032917          1.691862
# 0.770000                 399.946089     9.599748          1.740165
# ...                             ...          ...               ...
# 5.529187                 401.131000    10.341000          1.714080
# 5.529390                 401.029000    10.340400          1.713990
# 5.529593                 403.687000    10.339800          1.713900
# 5.529797                 405.080000    10.339700          1.713810
# 5.530000                 400.118455     9.819079          1.707561
#
#                       Flotation Column 01 Air Flow  \
# % Silica Concentrate
# 0.600000                                299.788706
# 0.660000                                299.946906
# 0.740000                                299.857589
# 0.750000                                299.739750
# 0.770000                                250.016756
# ...                                            ...
# 5.529187                                300.249000
# 5.529390                                299.869000
# 5.529593                                299.937000
# 5.529797                                300.528000
# 5.530000                                299.795376
#
#                       Flotation Column 02 Air Flow  \
# % Silica Concentrate
# 0.600000                                249.868783
# 0.660000                                300.510120
# 0.740000                                249.901839
# 0.750000                                250.036283
# 0.770000                                249.942567
# ...                                            ...
# 5.529187                                292.510000
# 5.529390                                298.185000
# 5.529593                                298.919000
# 5.529797                                292.035000
# 5.530000                                299.886991
#
#                       Flotation Column 03 Air Flow  ...  \
# % Silica Concentrate                                ...
# 0.600000                                299.859722  ...
# 0.660000                                299.952711  ...
# 0.740000                                299.920178  ...
# 0.750000                                299.923211  ...
# 0.770000                                250.024272  ...
# ...                                            ...  ...
# 5.529187                                297.188000  ...
# 5.529390                                298.148000  ...
# 5.529593                                300.501000  ...
# 5.529797                                302.124000  ...
# 5.530000                                299.883157  ...
#
#                       Flotation Column 06 Air Flow  \
# % Silica Concentrate
# 0.600000                                299.580378
# 0.660000                                249.966511
# 0.740000                                299.991356
# 0.750000                                299.779978
# 0.770000                                250.022533
# ...                                            ...
# 5.529187                                291.279000
# 5.529390                                298.651000
# 5.529593                                308.092000
# 5.529797                                299.051000
# 5.530000                                299.776535
#
#                       Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# % Silica Concentrate
# 0.600000                                287.760011                 549.482956
# 0.660000                                250.045646                 553.295064
# 0.740000                                299.922417                 550.379206
# 0.750000                                250.008144                 556.294867
# 0.770000                                250.085961                 603.269472
# ...                                            ...                        ...
# 5.529187                                302.016000                 400.282000
# 5.529390                                299.579000                 373.471000
# 5.529593                                298.666000                 376.051000
# 5.529797                                299.060000                 444.451000
# 5.530000                                299.626998                 466.203320
#
#                       Flotation Column 02 Level  Flotation Column 03 Level  \
# % Silica Concentrate
# 0.600000                             548.923283                 549.972750
# 0.660000                             504.124909                 750.439797
# 0.740000                             549.588667                 549.821300
# 0.750000                             553.436206                 560.644808
# 0.770000                             600.161144                 601.072817
# ...                                         ...                        ...
# 5.529187                             440.689000                 390.901000
# 5.529390                             396.158000                 396.315000
# 5.529593                             383.141000                 394.713000
# 5.529797                             252.555000                 392.063000
# 5.530000                             470.200318                 543.103345
#
#                       Flotation Column 04 Level  Flotation Column 05 Level  \
# % Silica Concentrate
# 0.600000                             516.092072                 517.980733
# 0.660000                             454.544115                 453.474052
# 0.740000                             498.237644                 499.867883
# 0.750000                             562.173389                 550.175139
# 0.770000                             449.567033                 449.980850
# ...                                         ...                        ...
# 5.529187                             314.406000                 339.873000
# 5.529390                             356.765000                 352.086000
# 5.529593                             394.682000                 370.609000
# 5.529797                             334.993000                 340.588000
# 5.530000                             397.303592                 400.015793
#
#                       Flotation Column 06 Level  Flotation Column 07 Level  \
# % Silica Concentrate
# 0.600000                             511.288872                 513.563067
# 0.660000                             500.682550                 502.348081
# 0.740000                             499.730194                 498.209325
# 0.750000                             552.597044                 551.615594
# 0.770000                             447.103056                 450.250956
# ...                                         ...                        ...
# 5.529187                             353.915000                 371.580000
# 5.529390                             399.213000                 359.175000
# 5.529593                             452.038000                 368.375000
# 5.529797                             427.846000                 343.693000
# 5.530000                             401.980517                 399.966089
#
#                       % Iron Concentrate
# % Silica Concentrate
# 0.600000                       66.570000
# 0.660000                       65.120000
# 0.740000                       65.610000
# 0.750000                       66.780000
# 0.770000                       66.900000
# ...                                  ...
# 5.529187                       62.360000
# 5.529390                       62.360000
# 5.529593                       62.360000
# 5.529797                       62.360000
# 5.530000                       63.658947
#
# [55569 rows x 22 columns]

# %%
df.groupby(['% Iron Concentrate']).mean()
# Out:
#                     % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# % Iron Concentrate
# 62.050000                 57.08          13.35  2234.233667  542.608150
# 62.052219                 59.78           9.29  2179.080000  559.878000
# 62.053684                 54.38          17.41  2152.340000  576.782000
# 62.054438                 59.78           9.29  2176.350000  563.970000
# 62.055014                 59.78           9.29  2404.300000  580.116000
# ...                         ...            ...          ...         ...
# 67.630000                 64.03           6.26  4052.176444  450.924417
# 67.660000                 49.35          24.90  3077.049500  377.148094
# 67.670000                 48.81          25.31  3641.604167  404.219844
# 67.990000                 55.78          12.85  2588.626106  431.233456
# 68.010000                 47.79          27.08  4322.071578  517.330928
#
#                     Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# % Iron Concentrate
# 62.050000              400.167157     9.764361          1.766480
# 62.052219              396.816000     9.788190          1.771370
# 62.053684              404.297000     9.750870          1.783270
# 62.054438              397.320000     9.789000          1.770600
# 62.055014              399.114000     9.998960          1.783490
# ...                           ...          ...               ...
# 67.630000              400.162194    10.158235          1.594675
# 67.660000              400.064061    10.244143          1.658189
# 67.670000              380.739842     9.933260          1.704377
# 67.990000              400.952456    10.693607          1.543400
# 68.010000              399.700861    10.463737          1.732864
#
#                     Flotation Column 01 Air Flow  \
# % Iron Concentrate
# 62.050000                             275.036800
# 62.052219                             300.484000
# 62.053684                             250.269000
# 62.054438                             300.526000
# 62.055014                             299.487000
# ...                                          ...
# 67.630000                             299.930939
# 67.660000                             249.998239
# 67.670000                             299.911356
# 67.990000                             299.981528
# 68.010000                             299.859072
#
#                     Flotation Column 02 Air Flow  \
# % Iron Concentrate
# 62.050000                             275.150456
# 62.052219                             303.163000
# 62.053684                             257.080000
# 62.054438                             302.561000
# 62.055014                             306.062000
# ...                                          ...
# 67.630000                             299.651872
# 67.660000                             249.948056
# 67.670000                             298.836394
# 67.990000                             300.051550
# 68.010000                             299.737372
#
#                     Flotation Column 03 Air Flow  ...  \
# % Iron Concentrate                                ...
# 62.050000                             274.954469  ...
# 62.052219                             302.548000  ...
# 62.053684                             251.587000  ...
# 62.054438                             301.143000  ...
# 62.055014                             301.820000  ...
# ...                                          ...  ...
# 67.630000                             299.908261  ...
# 67.660000                             250.111900  ...
# 67.670000                             299.982222  ...
# 67.990000                             299.870878  ...
# 68.010000                             299.957161  ...
#
#                     Flotation Column 06 Air Flow  \
# % Iron Concentrate
# 62.050000                             274.577364
# 62.052219                             297.373000
# 62.053684                             253.345000
# 62.054438                             298.174000
# 62.055014                             295.499000
# ...                                          ...
# 67.630000                             299.995489
# 67.660000                             299.998294
# 67.670000                             349.317211
# 67.990000                             299.905022
# 68.010000                             300.061800
#
#                     Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# % Iron Concentrate
# 62.050000                             275.109861                 569.033331
# 62.052219                             299.907000                 452.648000
# 62.053684                             251.807000                 605.591000
# 62.054438                             298.926000                 450.166000
# 62.055014                             296.715000                 465.839000
# ...                                          ...                        ...
# 67.630000                             299.936183                 500.537472
# 67.660000                             300.866928                 600.451433
# 67.670000                             349.772067                 500.660422
# 67.990000                             299.571333                 400.753367
# 68.010000                             299.814578                 500.424794
#
#                     Flotation Column 02 Level  Flotation Column 03 Level  \
# % Iron Concentrate
# 62.050000                          647.687120                 877.901875
# 62.052219                          464.109000                 870.505128
# 62.053684                          753.845963                 884.255629
# 62.054438                          459.298000                 870.491544
# 62.055014                          466.631000                 872.963834
# ...                                       ...                        ...
# 67.630000                          488.634144                 517.281154
# 67.660000                          599.180372                 600.377139
# 67.670000                          498.751794                 499.952850
# 67.990000                          397.946039                 399.183533
# 68.010000                          499.444217                 499.406578
#
#                     Flotation Column 04 Level  Flotation Column 05 Level  \
# % Iron Concentrate
# 62.050000                          374.896306                 372.729694
# 62.052219                          271.643000                 334.710000
# 62.053684                          430.078000                 380.590000
# 62.054438                          239.322000                 332.128000
# 62.055014                          386.357000                 354.618000
# ...                                       ...                        ...
# 67.630000                          497.519506                 497.175128
# 67.660000                          500.624361                 499.948867
# 67.670000                          353.228433                 350.180106
# 67.990000                          411.818111                 401.818483
# 68.010000                          499.020506                 499.049967
#
#                     Flotation Column 06 Level  Flotation Column 07 Level  \
# % Iron Concentrate
# 62.050000                          392.507081                 371.004833
# 62.052219                          268.534000                 289.385000
# 62.053684                          512.454000                 359.746000
# 62.054438                          327.958000                 322.669000
# 62.055014                          343.276000                 343.150000
# ...                                       ...                        ...
# 67.630000                          503.977833                 499.653206
# 67.660000                          449.454133                 448.839872
# 67.670000                          354.699483                 353.110700
# 67.990000                          398.992378                 405.573106
# 68.010000                          501.710136                 497.050772
#
#                     % Silica Concentrate
# % Iron Concentrate
# 62.050000                       4.100062
# 62.052219                       3.892902
# 62.053684                       4.532482
# 62.054438                       3.892982
# 62.055014                       3.878549
# ...                                  ...
# 67.630000                       1.050000
# 67.660000                       1.410000
# 67.670000                       1.030000
# 67.990000                       1.100000
# 68.010000                       1.380000
#
# [38696 rows x 22 columns]

# %% [markdown]
# Since dataset is very huge .Considering to split the data into train and test

# %%
# deleting date column

# %%
df=df.drop(['date'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
train,test=train_test_split(df,test_size=0.3)

# %%
print('Train size',train.shape)
print('Test size',test.shape)
# Out:
# Train size (515397, 23)
# Test size (220885, 23)

# %%
import missingno
missingno.matrix(train,figsize=(20,5))

# %%
import missingno
missingno.matrix(test,figsize=(20,5))

# %%
plt.figure(figsize=(30,30))
sns.heatmap(train.corr(),annot=True,linewidths=0.3)
plt.show()

# %%
train.columns[-1]
# Out:
# '% Silica Concentrate'

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515397 entries, 357056 to 65734
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   % Iron Feed                   515397 non-null  float64
#  1   % Silica Feed                 515397 non-null  float64
#  2   Starch Flow                   515397 non-null  float64
#  3   Amina Flow                    515397 non-null  float64
#  4   Ore Pulp Flow                 515397 non-null  float64
#  5   Ore Pulp pH                   515397 non-null  float64
#  6   Ore Pulp Density              515397 non-null  float64
#  7   Flotation Column 01 Air Flow  515397 non-null  float64
#  8   Flotation Column 02 Air Flow  515397 non-null  float64
#  9   Flotation Column 03 Air Flow  515397 non-null  float64
#  10  Flotation Column 04 Air Flow  515397 non-null  float64
#  11  Flotation Column 05 Air Flow  515397 non-null  float64
#  12  Flotation Column 06 Air Flow  515397 non-null  float64
#  13  Flotation Column 07 Air Flow  515397 non-null  float64
#  14  Flotation Column 01 Level     515397 non-null  float64
#  15  Flotation Column 02 Level     515397 non-null  float64
#  16  Flotation Column 03 Level     515397 non-null  float64
#  17  Flotation Column 04 Level     515397 non-null  float64
#  18  Flotation Column 05 Level     515397 non-null  float64
#  19  Flotation Column 06 Level     515397 non-null  float64
#  20  Flotation Column 07 Level     515397 non-null  float64
#  21  % Iron Concentrate            515397 non-null  float64
#  22  % Silica Concentrate          515397 non-null  float64
# dtypes: float64(23)
# memory usage: 94.4 MB

# %%
train.describe()
# Out:
#          % Iron Feed  % Silica Feed    Starch Flow     Amina Flow  \
# count  515397.000000  515397.000000  515397.000000  515397.000000
# mean       56.292887      14.655403    2870.114997     488.227427
# std         5.160721       6.813771    1216.520836      91.187664
# min        42.740000       1.310000       0.006614     241.688000
# 25%        52.610000       8.940000    2075.010000     431.970000
# 50%        56.080000      13.850000    3019.870000     504.417000
# 75%        59.720000      19.600000    3728.610000     553.255000
# max        65.780000      33.400000    6300.230000     739.538000
#
#        Ore Pulp Flow    Ore Pulp pH  Ore Pulp Density  \
# count  515397.000000  515397.000000     515397.000000
# mean      397.563786       9.767309          1.680551
# std         9.709799       0.387210          0.069130
# min       376.249000       8.753340          1.519820
# 25%       394.237000       9.527280          1.647560
# 50%       399.237000       9.796860          1.697690
# 75%       402.963000      10.038000          1.728470
# max       418.640000      10.808100          1.853229
#
#        Flotation Column 01 Air Flow  Flotation Column 02 Air Flow  \
# count                 515397.000000                 515397.000000
# mean                     280.153332                    277.166488
# std                       29.597448                     30.135387
# min                      175.510000                    175.156000
# 25%                      250.281000                    250.465000
# 50%                      299.341000                    296.218000
# 75%                      300.146000                    300.694000
# max                      373.871000                    375.992000
#
#        Flotation Column 03 Air Flow  ...  Flotation Column 07 Air Flow  \
# count                 515397.000000  ...                 515397.000000
# mean                     281.089621  ...                    290.764734
# std                       28.541648  ...                     28.671235
# min                      176.477751  ...                    185.962000
# 25%                      250.856000  ...                    256.235000
# 50%                      298.691000  ...                    299.005000
# 75%                      300.389000  ...                    301.918000
# max                      364.346000  ...                    371.593000
#
#        Flotation Column 01 Level  Flotation Column 02 Level  \
# count              515397.000000              515397.000000
# mean                  520.013237                 522.417046
# std                   130.999485                 128.191888
# min                   149.293000                 210.752000
# 25%                   416.827000                 441.797000
# 50%                   491.682000                 495.826000
# 75%                   594.080000                 595.157000
# max                   862.274000                 828.919000
#
#        Flotation Column 03 Level  Flotation Column 04 Level  \
# count              515397.000000              515397.000000
# mean                  531.267667                 420.067394
# std                   150.871084                  91.782214
# min                   126.255000                 162.201000
# 25%                   411.234000                 356.524000
# 50%                   494.134000                 411.651000
# 75%                   601.257000                 485.220000
# max                   886.822000                 680.359000
#
#        Flotation Column 05 Level  Flotation Column 06 Level  \
# count              515397.000000              515397.000000
# mean                  425.068928                 429.830867
# std                    84.473448                  89.920558
# min                   166.991000                 156.451000
# 25%                   357.585000                 358.368000
# 50%                   408.573000                 424.335000
# 75%                   484.015000                 492.741000
# max                   675.644000                 698.861000
#
#        Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# count              515397.000000       515397.000000         515397.000000
# mean                  420.784607           65.049199              2.326182
# std                    84.926690            1.117979              1.124580
# min                   175.377000           62.050000              0.600000
# 25%                   356.561000           64.370000              1.440000
# 50%                   410.745000           65.210000              2.000000
# 75%                   475.930000           65.860000              3.010000
# max                   659.883000           68.010000              5.530000
#
# [8 rows x 23 columns]

# %% [markdown]
# ## % for Iron Concentration

# %%
import statsmodels.api as sm

# %%
# Deleting date columns and % Iron Concentration
y=train['% Iron Concentrate']
X=train.drop(['% Iron Concentrate'],axis=1)

# %%
# Backward Elimination
cols=list(X.columns)
pmax=1
while len(cols)>0:
    p=[]
    C=X[cols]
    xc=sm.add_constant(C)
    model=sm.OLS(y,xc).fit()
    p=pd.Series(model.pvalues.values[1:],index=cols)
    pmax=max(p)
    feature_with_p_max=p.idxmax()
    if pmax>0.05:
        cols.remove(feature_with_p_max)
    else:
        break
        
selected_cols=cols
print(selected_cols)
# Out:
# ['% Iron Feed', '% Silica Feed', 'Starch Flow', 'Amina Flow', 'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density', 'Flotation Column 01 Air Flow', 'Flotation Column 02 Air Flow', 'Flotation Column 03 Air Flow', 'Flotation Column 04 Air Flow', 'Flotation Column 05 Air Flow', 'Flotation Column 06 Air Flow', 'Flotation Column 07 Air Flow', 'Flotation Column 01 Level', 'Flotation Column 02 Level', 'Flotation Column 03 Level', 'Flotation Column 04 Level', 'Flotation Column 05 Level', 'Flotation Column 06 Level', 'Flotation Column 07 Level', '% Silica Concentrate']

# %% [markdown]
# ## 1. Base Model

# %%
import statsmodels.api as sm
xc=sm.add_constant(X[selected_cols])
xc=xc.drop([],axis=1)
model=sm.OLS(y,xc).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     % Iron Concentrate   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                 4.823e+04
# Date:                Tue, 04 Aug 2020   Prob (F-statistic):               0.00
# Time:                        23:19:13   Log-Likelihood:            -5.0068e+05
# No. Observations:              515397   AIC:                         1.001e+06
# Df Residuals:                  515374   BIC:                         1.002e+06
# Df Model:                          22
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           56.5710      0.181    313.030      0.000      56.217      56.925
# % Iron Feed                      0.0347      0.001     45.689      0.000       0.033       0.036
# % Silica Feed                    0.0333      0.001     58.288      0.000       0.032       0.034
# Starch Flow                   -3.94e-06   8.23e-07     -4.788      0.000   -5.55e-06   -2.33e-06
# Amina Flow                      -0.0007   1.46e-05    -46.185      0.000      -0.001      -0.001
# Ore Pulp Flow                    0.0075      0.000     73.384      0.000       0.007       0.008
# Ore Pulp pH                      0.2136      0.003     84.375      0.000       0.209       0.219
# Ore Pulp Density                 1.1537      0.018     63.048      0.000       1.118       1.190
# Flotation Column 01 Air Flow    -0.0023      0.000    -22.054      0.000      -0.003      -0.002
# Flotation Column 02 Air Flow    -0.0023   6.16e-05    -37.049      0.000      -0.002      -0.002
# Flotation Column 03 Air Flow     0.0014      0.000     12.143      0.000       0.001       0.002
# Flotation Column 04 Air Flow    -0.0139      0.000    -31.049      0.000      -0.015      -0.013
# Flotation Column 05 Air Flow     0.0214      0.000     79.323      0.000       0.021       0.022
# Flotation Column 06 Air Flow    -0.0015   6.15e-05    -23.598      0.000      -0.002      -0.001
# Flotation Column 07 Air Flow     0.0015   6.42e-05     23.246      0.000       0.001       0.002
# Flotation Column 01 Level       -0.0003   1.16e-05    -23.670      0.000      -0.000      -0.000
# Flotation Column 02 Level       -0.0002   1.06e-05    -16.000      0.000      -0.000      -0.000
# Flotation Column 03 Level       -0.0002   9.18e-06    -22.767      0.000      -0.000      -0.000
# Flotation Column 04 Level    -3.262e-05   1.39e-05     -2.341      0.019   -5.99e-05   -5.31e-06
# Flotation Column 05 Level        0.0003   1.74e-05     19.892      0.000       0.000       0.000
# Flotation Column 06 Level       -0.0003   1.34e-05    -21.877      0.000      -0.000      -0.000
# Flotation Column 07 Level        0.0004   1.64e-05     24.576      0.000       0.000       0.000
# % Silica Concentrate            -0.7893      0.001   -917.947      0.000      -0.791      -0.788
# ==============================================================================
# Omnibus:                    23066.675   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            31532.428
# Skew:                          -0.445   Prob(JB):                         0.00
# Kurtosis:                       3.823   Cond. No.                     7.01e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.01e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
residuals=model.resid
sns.distplot(residuals)

# %%
import scipy.stats as stats
stats.probplot(residuals,plot=plt)
plt.show()

# %% [markdown]
# ### Autocorrelation Check

# %%
import statsmodels.tsa.api as smt
acf=smt.graphics.plot_acf(residuals,lags=40)
acf.show()
# Out:
# C:\Users\pravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Multicollinearity Check

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
pd.DataFrame({'vif':vif},index=X.columns).T
# Out:
#      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  Ore Pulp Flow  \
# vif  2155.017052      100.69421     8.285207   65.829615    2011.140403
#
#      Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# vif    768.69808       1130.974112                   1109.474321
#
#      Flotation Column 02 Air Flow  Flotation Column 03 Air Flow  ...  \
# vif                    371.491769                   1344.179965  ...
#
#      Flotation Column 06 Air Flow  Flotation Column 07 Air Flow  \
# vif                    406.960809                    431.109486
#
#      Flotation Column 01 Level  Flotation Column 02 Level  \
# vif                  48.614155                  41.345935
#
#      Flotation Column 03 Level  Flotation Column 04 Level  \
# vif                  32.416953                   45.24756
#
#      Flotation Column 05 Level  Flotation Column 06 Level  \
# vif                  71.142114                  42.977272
#
#      Flotation Column 07 Level  % Silica Concentrate
# vif                  62.460092              6.223508
#
# [1 rows x 22 columns]

# %%
from sklearn import metrics

# %% [markdown]
# ### 2.Linear Regression -ML

# %%
y=train['% Iron Concentrate']
X=train.drop(['% Iron Concentrate'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                        test_size=0.30, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred=lr.predict(X_train)
print ("intercept:",lr.intercept_)
print ("n_coefficients:         ",lr.coef_)
# Out:
# intercept: 56.27526061476651
# n_coefficients:          [ 3.56094906e-02  3.39894981e-02 -4.34623380e-06 -6.61550867e-04
#   7.53296469e-03  2.11973924e-01  1.16044532e+00 -2.38857004e-03
#  -2.26263316e-03  1.37051519e-03 -1.32943020e-02  2.15105747e-02
#  -1.40394928e-03  1.50236511e-03 -2.90818291e-04 -1.61310989e-04
#  -2.11409978e-04 -2.57693465e-05  3.47940286e-04 -2.78261336e-04
#   4.08541557e-04 -7.89508016e-01]

# %%
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6728726370393988
# Mean absolute Error:  0.49901749763720704
# Mean square Error:  0.4085125244582316
# RMSE:  0.6391498450740887

# %%
y_test_pred=lr.predict(X_test)

# %%
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.6735068992899291
# Mean absolute Error:  0.5001841248212665
# Mean square Error:  0.4089024928160149
# RMSE:  0.6394548403257378

# %% [markdown]
# ### Model using Backward Elimination Model

# %% [markdown]
# ### 4.Lasso/Ridge/ElasticNet

# %% [markdown]
# ## 4.1 Lasso

# %%
from sklearn.linear_model import Lasso,LassoCV
lasso=Lasso(alpha=0.001,normalize=True)

# %%
lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.001, normalize=True)

# %%
y_train_pred=lasso.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.35056837933196905
# L1 Mean absolute Error:  0.7168707920583395
# L2 Mean square Error:  0.811002015915283
# L2 RMSE:  0.9005565034551042

# %%
y_test_pred=lasso.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.35086273458373596
# Mean absolute Error:  0.7177053067173013
# Mean square Error:  0.8129845483142055
# RMSE:  0.9016565578501636

# %%
n_alphas = 50
alphas = np.linspace(0.1,4.5, n_alphas)
coefs=[]
lasso = Lasso()
for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(X, y)
    coefs.append(lasso.coef_)
    
plt.plot(alphas, coefs)
plt.xlabel('alphas')
plt.ylabel('coefs')
plt.show()

# %%
n_alphas=50
alphas=np.linspace(0.1,1, n_alphas)

lasso_cv = LassoCV(alphas=alphas, cv=3, random_state=22)
lasso_cv.fit(X,y)
# Out:
# LassoCV(alphas=array([0.1       , 0.11836735, 0.13673469, 0.15510204, 0.17346939,
#        0.19183673, 0.21020408, 0.22857143, 0.24693878, 0.26530612,
#        0.28367347, 0.30204082, 0.32040816, 0.33877551, 0.35714286,
#        0.3755102 , 0.39387755, 0.4122449 , 0.43061224, 0.44897959,
#        0.46734694, 0.48571429, 0.50408163, 0.52244898, 0.54081633,
#        0.55918367, 0.57755102, 0.59591837, 0.61428571, 0.63265306,
#        0.65102041, 0.66938776, 0.6877551 , 0.70612245, 0.7244898 ,
#        0.74285714, 0.76122449, 0.77959184, 0.79795918, 0.81632653,
#        0.83469388, 0.85306122, 0.87142857, 0.88979592, 0.90816327,
#        0.92653061, 0.94489796, 0.96326531, 0.98163265, 1.        ]),
#         cv=3, random_state=22)

# %%
lasso_cv.alpha_
# Out:
# 0.1

# %%
lasso = Lasso(alpha=lasso_cv.alpha_)
lasso.fit(X_train, y_train)
lasso.coef_
pd.DataFrame(lasso.coef_, X.columns, columns=['coefs'])
# Out:
#                                  coefs
# % Iron Feed                  -0.000000
# % Silica Feed                 0.004046
# Starch Flow                   0.000023
# Amina Flow                   -0.000172
# Ore Pulp Flow                 0.007231
# Ore Pulp pH                   0.000000
# Ore Pulp Density              0.000000
# Flotation Column 01 Air Flow -0.000052
# Flotation Column 02 Air Flow -0.001963
# Flotation Column 03 Air Flow -0.000000
# Flotation Column 04 Air Flow -0.000000
# Flotation Column 05 Air Flow  0.013660
# Flotation Column 06 Air Flow -0.001901
# Flotation Column 07 Air Flow  0.000710
# Flotation Column 01 Level    -0.000218
# Flotation Column 02 Level    -0.000110
# Flotation Column 03 Level    -0.000226
# Flotation Column 04 Level     0.000055
# Flotation Column 05 Level     0.000367
# Flotation Column 06 Level    -0.000339
# Flotation Column 07 Level     0.000493
# % Silica Concentrate         -0.715168

# %%
y_train_pred=lasso.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6546696800355898
# Mean absolute Error:  0.5197502541614583
# Mean square Error:  0.43124414755124163
# RMSE:  0.6566918208347364

# %%
y_test_pred=lasso.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.6552822696743197
# Mean absolute Error:  0.5209928008539692
# Mean square Error:  0.4317271603641624
# RMSE:  0.6570594800808847

# %% [markdown]
# ### 4.2 Ridge

# %%
from sklearn.linear_model import Ridge,RidgeCV
ridge=Ridge(alpha=0.05)

# %%
ridge.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.05)

# %%
y_train_pred=ridge.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6728726370307054
# Mean absolute Error:  0.4990174945957087
# Mean square Error:  0.40851252446908787
# RMSE:  0.6391498450825814

# %%
y_test_pred=ridge.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.6735069049018458
# Mean absolute Error:  0.5001841272011355
# Mean square Error:  0.40890248578760674
# RMSE:  0.6394548348301127

# %%
ridge.fit(X, y)
ridge.coef_
pd.DataFrame(ridge.coef_, X.columns, columns=['coefs'])
# Out:
#                                  coefs
# % Iron Feed                   0.034665
# % Silica Feed                 0.033283
# Starch Flow                  -0.000004
# Amina Flow                   -0.000675
# Ore Pulp Flow                 0.007509
# Ore Pulp pH                   0.213633
# Ore Pulp Density              1.153645
# Flotation Column 01 Air Flow -0.002326
# Flotation Column 02 Air Flow -0.002281
# Flotation Column 03 Air Flow  0.001403
# Flotation Column 04 Air Flow -0.013915
# Flotation Column 05 Air Flow  0.021395
# Flotation Column 06 Air Flow -0.001451
# Flotation Column 07 Air Flow  0.001492
# Flotation Column 01 Level    -0.000274
# Flotation Column 02 Level    -0.000170
# Flotation Column 03 Level    -0.000209
# Flotation Column 04 Level    -0.000033
# Flotation Column 05 Level     0.000346
# Flotation Column 06 Level    -0.000292
# Flotation Column 07 Level     0.000403
# % Silica Concentrate         -0.789317

# %%
n_alphas = 200
alphas = np.logspace(-3, 2, n_alphas)
coefs=[]
model = Ridge()
for a in alphas:
    model.set_params(alpha=a)
    model.fit(X, y)
    coefs.append(model.coef_)
    
plt.plot(alphas, coefs)
plt.xlabel('alphas')
plt.ylabel('coefs')
plt.show()

# %%
n_alphas = 1000
alphas = np.logspace(-2, 0)

ridge_cv = RidgeCV(alphas=alphas, store_cv_values=True)
ridge_cv.fit(X, y)

ridge_cv.alpha_
# Out:
# 0.42919342601287763

# %%
ridge=Ridge(alpha=ridge_cv.alpha_)
ridge.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.42919342601287763)

# %%
y_train_pred=ridge.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6728726363994058
# Mean absolute Error:  0.49901747182606054
# Mean square Error:  0.4085125252574468
# RMSE:  0.6391498456993061

# %%
y_test_pred=ridge.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.6735069468708961
# Mean absolute Error:  0.5001841453272013
# Mean square Error:  0.4089024332252425
# RMSE:  0.6394547937307551

# %% [markdown]
# ### 4.3 Elastic Net/Elastic Net CV

# %%
from sklearn.linear_model import ElasticNet, ElasticNetCV
enet = ElasticNet(alpha=0.1)
enet.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.1)

# %%
y_train_pred=enet.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6577093247520385
# Mean absolute Error:  0.5166780901637973
# Mean square Error:  0.4274482775716273
# RMSE:  0.6537952872051215

# %%
y_test_pred=enet.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.6583391519916373
# Mean absolute Error:  0.5180176476980574
# Mean square Error:  0.427898697229481
# RMSE:  0.6541396618685348

# %%
pd.DataFrame(enet.coef_, X.columns, columns=['coefs'])
# Out:
#                                  coefs
# % Iron Feed                   0.000000
# % Silica Feed                 0.005942
# Starch Flow                   0.000023
# Amina Flow                   -0.000178
# Ore Pulp Flow                 0.007630
# Ore Pulp pH                   0.000000
# Ore Pulp Density              0.000000
# Flotation Column 01 Air Flow -0.000140
# Flotation Column 02 Air Flow -0.002152
# Flotation Column 03 Air Flow  0.000000
# Flotation Column 04 Air Flow -0.003702
# Flotation Column 05 Air Flow  0.017512
# Flotation Column 06 Air Flow -0.002170
# Flotation Column 07 Air Flow  0.001389
# Flotation Column 01 Level    -0.000244
# Flotation Column 02 Level    -0.000127
# Flotation Column 03 Level    -0.000224
# Flotation Column 04 Level     0.000069
# Flotation Column 05 Level     0.000354
# Flotation Column 06 Level    -0.000355
# Flotation Column 07 Level     0.000499
# % Silica Concentrate         -0.727140

# %%
n_alphas = 100
alphas = np.logspace(-3, -1, n_alphas)
coefs=[]
enet = ElasticNet()
for a in alphas:
    enet.set_params(alpha=a)
    enet.fit(X, y)
    coefs.append(model.coef_)
    
plt.plot(alphas, coefs)
plt.xlabel('alphas')
plt.ylabel('coefs')
plt.show()

# %%
n_alphas = 100
alphas = np.logspace(-3, 1, n_alphas)

en_cv = ElasticNetCV(alphas=alphas, cv=3)
en_cv.fit(X, y)
en_cv.alpha_
# Out:
# 0.001

# %%
enet = ElasticNet(alpha=en_cv.alpha_)
enet.fit(X_train,y_train)
# Out:
# ElasticNet(alpha=0.001)

# %%
y_train_pred=enet.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6726045266488161
# Mean absolute Error:  0.4992721123206065
# Mean square Error:  0.40884733733202855
# RMSE:  0.639411711913403

# %%
y_train_pred=enet.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6726045266488161
# Mean absolute Error:  0.4992721123206065
# Mean square Error:  0.40884733733202855
# RMSE:  0.639411711913403

# %% [markdown]
# ## 3. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### Changing max depth

# %%
train_accuracy=[]
test_accuracy=[]

for depth in range(5,20):
    dt_model=DecisionTreeRegressor(max_depth=depth,random_state=42)
    dt_model.fit(X_train,y_train)
    train_accuracy.append(dt_model.score(X_train,y_train))
    test_accuracy.append(dt_model.score(X_test,y_test))

# %%
frame=pd.DataFrame({'max_depth':range(5,20),'train_accuracy':train_accuracy,'test_accuracy':test_accuracy})
print(frame)
# Out:
#     max_depth  train_accuracy  test_accuracy
# 0           5        0.689081       0.690052
# 1           6        0.707996       0.708201
# 2           7        0.728646       0.728606
# 3           8        0.753366       0.751788
# 4           9        0.780673       0.777335
# 5          10        0.806976       0.802936
# 6          11        0.834666       0.829846
# 7          12        0.861976       0.855599
# 8          13        0.886025       0.878717
# 9          14        0.906927       0.898695
# 10         15        0.925400       0.916549
# 11         16        0.941425       0.931051
# 12         17        0.954228       0.943614
# 13         18        0.964310       0.952819
# 14         19        0.973222       0.960703

# %%
plt.figure(figsize=(13,6))
plt.plot(frame['max_depth'],frame['train_accuracy'],marker='o')
plt.plot(frame['max_depth'],frame['test_accuracy'],marker='o')
plt.xlabel('Depth of Tree')
plt.axhline(y=0.95, color='r', linestyle='-')
plt.ylabel('Accuracy Performance')
plt.show()

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
print ("feature_importances:",dtr.feature_importances_)
print ("Best params: \n        ",dtr.get_params)
print('n feature',dtr.n_features_)
print(dtr.n_outputs_)
# Out:
# feature_importances: [0.0339093  0.03783269 0.01053051 0.01570264 0.01725949 0.02921003
#  0.01883963 0.00678437 0.00940565 0.00210424 0.02626233 0.0126414
#  0.00429637 0.00217284 0.01182105 0.00913532 0.01772773 0.00325404
#  0.00772846 0.00890823 0.00237184 0.71210182]
# Best params:
#          <bound method BaseEstimator.get_params of DecisionTreeRegressor()>
# n feature 22
# 1

# %%
y_train_pred=dtr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  1.0
# Mean absolute Error:  7.280592822468505e-14
# Mean square Error:  4.0550063748592826e-26
# RMSE:  2.0137046394293486e-13

# %%
y_test_pred=dtr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.9854932161934297
# Mean absolute Error:  0.016595802418923358
# Mean square Error:  0.018168408607559437
# RMSE:  0.1347902392889019

# %% [markdown]
# ## 4. Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
print ("feature_importances:",rfr.feature_importances_)
print ("n_coefficients:         ",rfr.get_params)
print('n feature',rfr.n_features_)
print(rfr.n_outputs_)
# Out:
# feature_importances: [0.03289369 0.03746302 0.01063357 0.01525379 0.01748502 0.02985938
#  0.01815026 0.00674982 0.00773987 0.00331963 0.02337712 0.01304692
#  0.00493613 0.00227123 0.01305535 0.00964822 0.01854114 0.00358655
#  0.00803195 0.00985783 0.00206748 0.71203201]
# n_coefficients:          <bound method BaseEstimator.get_params of RandomForestRegressor()>
# n feature 22
# 1

# %%
y_train_pred=rfr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.9993812409729241
# Mean absolute Error:  0.007866422463211292
# Mean square Error:  0.0007726984679436346
# RMSE:  0.02779745434286447

# %%
y_test_pred=rfr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.9955840292522259
# Mean absolute Error:  0.02056238158381494
# Mean square Error:  0.005530596031096333
# RMSE:  0.0743679771884131

# %% [markdown]
# ## Gradient Boosting

# %%
params = {
    'n_estimators': 80,
    'max_depth': 12,
    'learning_rate': 0.1,
    'criterion': 'mse'
    }

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(**params)

# %%
gbr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(criterion='mse', max_depth=12, n_estimators=80)

# %%
y_train_pred=gbr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.9907712828805283
# Mean absolute Error:  0.07071247105340218
# Mean square Error:  0.011524705527126242
# RMSE:  0.10735318126225343

# %%
y_test_pred=gbr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.9869262024761256
# Mean absolute Error:  0.0801449160569615
# Mean square Error:  0.016373725467575203
# RMSE:  0.12795985881351699

# %% [markdown]
# ## Considering Random Forest Regressor Base Model as the final model. Implementing the model in the test data set

# %%
test
# Out:
#         % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  Ore Pulp Flow  \
# 714499        54.14          14.69  2575.780000  560.731000      386.77600
# 658795        59.21           9.69  3322.850000  503.862000      386.01200
# 299166        64.03           6.26  2828.130000  380.490000      398.37600
# 12706         59.05          11.20  3935.940000  533.020000      401.80700
# 651430        47.90          28.59  2901.350000  529.513000      380.21900
# ...             ...            ...          ...         ...            ...
# 321544        64.03           6.26  3028.080000  560.913000      397.26600
# 174257        53.12          21.26   199.362000  588.242000      399.54400
# 572343        57.46          10.80  1010.527208  289.740662      394.64122
# 20735         58.19          10.84  3437.010000  536.499000      396.62100
# 248323        64.03           6.26  3578.110000  565.520000      403.05300
#
#         Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 714499      9.66395          1.704810                       299.748
# 658795      9.84527          1.716960                       299.694
# 299166      9.68004          1.667010                       300.366
# 12706      10.11630          1.760000                       248.071
# 651430      9.69336          1.703590                       299.765
# ...             ...               ...                           ...
# 321544      9.05020          1.676110                       299.487
# 174257      9.38634          1.778860                       300.416
# 572343      9.84271          1.526654                       298.956
# 20735       9.38595          1.720000                       248.928
# 248323      9.74434          1.688810                       300.690
#
#         Flotation Column 02 Air Flow  Flotation Column 03 Air Flow  ...  \
# 714499                       299.691                       298.581  ...
# 658795                       296.760                       302.189  ...
# 299166                       303.631                       298.768  ...
# 12706                        251.104                       248.005  ...
# 651430                       297.303                       302.344  ...
# ...                              ...                           ...  ...
# 321544                       254.004                       301.245  ...
# 174257                       298.028                       298.680  ...
# 572343                       244.428                       300.260  ...
# 20735                        245.215                       250.049  ...
# 248323                       307.214                       298.749  ...
#
#         Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# 714499                       299.300                 379.519000
# 658795                       294.537                 488.300000
# 299166                       303.244                 601.206000
# 12706                        246.401                 539.727000
# 651430                       305.815                 499.309000
# ...                              ...                        ...
# 321544                       302.783                 491.479000
# 174257                       296.465                 452.486000
# 572343                       349.316                 797.369103
# 20735                        249.697                 448.187000
# 248323                       299.869                 450.733000
#
#         Flotation Column 02 Level  Flotation Column 03 Level  \
# 714499                    576.245                    397.070
# 658795                    467.794                    719.210
# 299166                    603.278                    601.478
# 12706                     548.901                    555.091
# 651430                    507.439                    408.762
# ...                           ...                        ...
# 321544                    513.164                    602.139
# 174257                    436.343                    449.319
# 572343                    551.365                    595.629
# 20735                     449.951                    474.209
# 248323                    442.096                    452.174
#
#         Flotation Column 04 Level  Flotation Column 05 Level  \
# 714499                    372.257                 363.828000
# 658795                    606.692                 310.039000
# 299166                    511.966                 480.454000
# 12706                     566.054                 541.471000
# 651430                    392.907                 359.660000
# ...                           ...                        ...
# 321544                    401.172                 398.766000
# 174257                    318.206                 350.093000
# 572343                    460.445                 655.539983
# 20735                     434.452                 409.615000
# 248323                    323.532                 345.464000
#
#         Flotation Column 06 Level  Flotation Column 07 Level  \
# 714499                 622.612000                 330.701000
# 658795                 547.506000                 368.059000
# 299166                 501.750000                 482.858000
# 12706                  568.404000                 491.509000
# 651430                 278.368000                 462.025000
# ...                           ...                        ...
# 321544                 401.562000                 408.853000
# 174257                 321.310000                 347.688000
# 572343                 260.171195                 578.028222
# 20735                  463.730000                 427.063000
# 248323                 337.056000                 366.034000
#
#         % Iron Concentrate  % Silica Concentrate
# 714499               63.82                  2.25
# 658795               64.49                  1.68
# 299166               66.91                  1.39
# 12706                67.22                  1.00
# 651430               64.80                  1.24
# ...                    ...                   ...
# 321544               65.09                  1.46
# 174257               64.56                  2.98
# 572343               65.44                  2.08
# 20735                64.63                  3.77
# 248323               64.46                  1.29
#
# [220885 rows x 23 columns]

# %%
expected_output=train['% Iron Concentrate']
expected_input=train.drop(['% Iron Concentrate'],axis=1)

# %%
y_pred=rfr.predict(expected_input)

# %%
print('R2 of Output: ', metrics.r2_score(expected_output,y_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(expected_output,y_pred))
print('Mean square Error: ',metrics.mean_squared_error(expected_output,y_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(expected_output,y_pred)))
# Out:
# R2 of Output:  0.9982397634736245
# Mean absolute Error:  0.011675232369415124
# Mean square Error:  0.0022000760452571813
# RMSE:  0.04690496823639455
