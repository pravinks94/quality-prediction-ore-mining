# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('DATA/MiningProcess_Flotation_Plant_Database.csv',decimal=',').drop_duplicates()
df.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1  2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2  2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3  2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4  2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
#    Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# 0                       253.235  ...                       250.884
# 1                       250.532  ...                       248.994
# 2                       247.874  ...                       248.071
# 3                       254.487  ...                       251.147
# 4                       252.136  ...                       248.928
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    457.396                    432.962
# 1                    451.891                    429.560
# 2                    451.240                    468.927
# 3                    452.441                    458.165
# 4                    452.441                    452.900
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    424.954                    443.558
# 1                    432.939                    448.086
# 2                    434.610                    449.688
# 3                    442.865                    446.210
# 4                    450.523                    453.670
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                    502.255                    446.370
# 1                    496.363                    445.922
# 2                    484.411                    447.826
# 3                    471.411                    437.690
# 4                    462.598                    443.682
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                    523.344               66.91                  1.31
# 1                    498.075               66.91                  1.31
# 2                    458.567               66.91                  1.31
# 3                    427.669               66.91                  1.31
# 4                    425.679               66.91                  1.31
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (736282, 24)

# %%
df.columns
# Out:
# Index(['date', '% Iron Feed', '% Silica Feed', 'Starch Flow', 'Amina Flow',
#        'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density',
#        'Flotation Column 01 Air Flow', 'Flotation Column 02 Air Flow',
#        'Flotation Column 03 Air Flow', 'Flotation Column 04 Air Flow',
#        'Flotation Column 05 Air Flow', 'Flotation Column 06 Air Flow',
#        'Flotation Column 07 Air Flow', 'Flotation Column 01 Level',
#        'Flotation Column 02 Level', 'Flotation Column 03 Level',
#        'Flotation Column 04 Level', 'Flotation Column 05 Level',
#        'Flotation Column 06 Level', 'Flotation Column 07 Level',
#        '% Iron Concentrate', '% Silica Concentrate'],
#       dtype='object')

# %%
df.groupby(['% Silica Concentrate']).mean()
# Out:
#                       % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# % Silica Concentrate
# 0.600000                    48.81          25.31  3507.572389  430.847311
# 0.660000                    48.81          25.31  2185.361279  419.244482
# 0.740000                    48.81          25.31  3890.823333  458.506367
# 0.750000                    48.81          25.31  2975.124778  393.377690
# 0.770000                    56.45          13.57  2169.709250  505.566494
# ...                           ...            ...          ...         ...
# 5.529187                    57.46          10.80  4851.520000  656.820000
# 5.529390                    57.46          10.80  4836.140000  624.736000
# 5.529593                    57.46          10.80  4824.430000  642.565000
# 5.529797                    57.46          10.80  4801.680000  637.808000
# 5.530000                    49.80          22.34  3414.716557  584.756947
#
#                       Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# % Silica Concentrate
# 0.600000                 379.343667    10.291061          1.700894
# 0.660000                 381.502420     9.469579          1.684721
# 0.740000                 381.110714    10.395589          1.687037
# 0.750000                 381.802851    10.032917          1.691862
# 0.770000                 399.946089     9.599748          1.740165
# ...                             ...          ...               ...
# 5.529187                 401.131000    10.341000          1.714080
# 5.529390                 401.029000    10.340400          1.713990
# 5.529593                 403.687000    10.339800          1.713900
# 5.529797                 405.080000    10.339700          1.713810
# 5.530000                 400.118455     9.819079          1.707561
#
#                       Flotation Column 01 Air Flow  \
# % Silica Concentrate
# 0.600000                                299.788706
# 0.660000                                299.946906
# 0.740000                                299.857589
# 0.750000                                299.739750
# 0.770000                                250.016756
# ...                                            ...
# 5.529187                                300.249000
# 5.529390                                299.869000
# 5.529593                                299.937000
# 5.529797                                300.528000
# 5.530000                                299.795376
#
#                       Flotation Column 02 Air Flow  \
# % Silica Concentrate
# 0.600000                                249.868783
# 0.660000                                300.510120
# 0.740000                                249.901839
# 0.750000                                250.036283
# 0.770000                                249.942567
# ...                                            ...
# 5.529187                                292.510000
# 5.529390                                298.185000
# 5.529593                                298.919000
# 5.529797                                292.035000
# 5.530000                                299.886991
#
#                       Flotation Column 03 Air Flow  ...  \
# % Silica Concentrate                                ...
# 0.600000                                299.859722  ...
# 0.660000                                299.952711  ...
# 0.740000                                299.920178  ...
# 0.750000                                299.923211  ...
# 0.770000                                250.024272  ...
# ...                                            ...  ...
# 5.529187                                297.188000  ...
# 5.529390                                298.148000  ...
# 5.529593                                300.501000  ...
# 5.529797                                302.124000  ...
# 5.530000                                299.883157  ...
#
#                       Flotation Column 06 Air Flow  \
# % Silica Concentrate
# 0.600000                                299.580378
# 0.660000                                249.966511
# 0.740000                                299.991356
# 0.750000                                299.779978
# 0.770000                                250.022533
# ...                                            ...
# 5.529187                                291.279000
# 5.529390                                298.651000
# 5.529593                                308.092000
# 5.529797                                299.051000
# 5.530000                                299.776535
#
#                       Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# % Silica Concentrate
# 0.600000                                287.760011                 549.482956
# 0.660000                                250.045646                 553.295064
# 0.740000                                299.922417                 550.379206
# 0.750000                                250.008144                 556.294867
# 0.770000                                250.085961                 603.269472
# ...                                            ...                        ...
# 5.529187                                302.016000                 400.282000
# 5.529390                                299.579000                 373.471000
# 5.529593                                298.666000                 376.051000
# 5.529797                                299.060000                 444.451000
# 5.530000                                299.626998                 466.203320
#
#                       Flotation Column 02 Level  Flotation Column 03 Level  \
# % Silica Concentrate
# 0.600000                             548.923283                 549.972750
# 0.660000                             504.124909                 750.439797
# 0.740000                             549.588667                 549.821300
# 0.750000                             553.436206                 560.644808
# 0.770000                             600.161144                 601.072817
# ...                                         ...                        ...
# 5.529187                             440.689000                 390.901000
# 5.529390                             396.158000                 396.315000
# 5.529593                             383.141000                 394.713000
# 5.529797                             252.555000                 392.063000
# 5.530000                             470.200318                 543.103345
#
#                       Flotation Column 04 Level  Flotation Column 05 Level  \
# % Silica Concentrate
# 0.600000                             516.092072                 517.980733
# 0.660000                             454.544115                 453.474052
# 0.740000                             498.237644                 499.867883
# 0.750000                             562.173389                 550.175139
# 0.770000                             449.567033                 449.980850
# ...                                         ...                        ...
# 5.529187                             314.406000                 339.873000
# 5.529390                             356.765000                 352.086000
# 5.529593                             394.682000                 370.609000
# 5.529797                             334.993000                 340.588000
# 5.530000                             397.303592                 400.015793
#
#                       Flotation Column 06 Level  Flotation Column 07 Level  \
# % Silica Concentrate
# 0.600000                             511.288872                 513.563067
# 0.660000                             500.682550                 502.348081
# 0.740000                             499.730194                 498.209325
# 0.750000                             552.597044                 551.615594
# 0.770000                             447.103056                 450.250956
# ...                                         ...                        ...
# 5.529187                             353.915000                 371.580000
# 5.529390                             399.213000                 359.175000
# 5.529593                             452.038000                 368.375000
# 5.529797                             427.846000                 343.693000
# 5.530000                             401.980517                 399.966089
#
#                       % Iron Concentrate
# % Silica Concentrate
# 0.600000                       66.570000
# 0.660000                       65.120000
# 0.740000                       65.610000
# 0.750000                       66.780000
# 0.770000                       66.900000
# ...                                  ...
# 5.529187                       62.360000
# 5.529390                       62.360000
# 5.529593                       62.360000
# 5.529797                       62.360000
# 5.530000                       63.658947
#
# [55569 rows x 22 columns]

# %%
df.groupby(['% Iron Concentrate']).mean()
# Out:
#                     % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# % Iron Concentrate
# 62.050000                 57.08          13.35  2234.233667  542.608150
# 62.052219                 59.78           9.29  2179.080000  559.878000
# 62.053684                 54.38          17.41  2152.340000  576.782000
# 62.054438                 59.78           9.29  2176.350000  563.970000
# 62.055014                 59.78           9.29  2404.300000  580.116000
# ...                         ...            ...          ...         ...
# 67.630000                 64.03           6.26  4052.176444  450.924417
# 67.660000                 49.35          24.90  3077.049500  377.148094
# 67.670000                 48.81          25.31  3641.604167  404.219844
# 67.990000                 55.78          12.85  2588.626106  431.233456
# 68.010000                 47.79          27.08  4322.071578  517.330928
#
#                     Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# % Iron Concentrate
# 62.050000              400.167157     9.764361          1.766480
# 62.052219              396.816000     9.788190          1.771370
# 62.053684              404.297000     9.750870          1.783270
# 62.054438              397.320000     9.789000          1.770600
# 62.055014              399.114000     9.998960          1.783490
# ...                           ...          ...               ...
# 67.630000              400.162194    10.158235          1.594675
# 67.660000              400.064061    10.244143          1.658189
# 67.670000              380.739842     9.933260          1.704377
# 67.990000              400.952456    10.693607          1.543400
# 68.010000              399.700861    10.463737          1.732864
#
#                     Flotation Column 01 Air Flow  \
# % Iron Concentrate
# 62.050000                             275.036800
# 62.052219                             300.484000
# 62.053684                             250.269000
# 62.054438                             300.526000
# 62.055014                             299.487000
# ...                                          ...
# 67.630000                             299.930939
# 67.660000                             249.998239
# 67.670000                             299.911356
# 67.990000                             299.981528
# 68.010000                             299.859072
#
#                     Flotation Column 02 Air Flow  \
# % Iron Concentrate
# 62.050000                             275.150456
# 62.052219                             303.163000
# 62.053684                             257.080000
# 62.054438                             302.561000
# 62.055014                             306.062000
# ...                                          ...
# 67.630000                             299.651872
# 67.660000                             249.948056
# 67.670000                             298.836394
# 67.990000                             300.051550
# 68.010000                             299.737372
#
#                     Flotation Column 03 Air Flow  ...  \
# % Iron Concentrate                                ...
# 62.050000                             274.954469  ...
# 62.052219                             302.548000  ...
# 62.053684                             251.587000  ...
# 62.054438                             301.143000  ...
# 62.055014                             301.820000  ...
# ...                                          ...  ...
# 67.630000                             299.908261  ...
# 67.660000                             250.111900  ...
# 67.670000                             299.982222  ...
# 67.990000                             299.870878  ...
# 68.010000                             299.957161  ...
#
#                     Flotation Column 06 Air Flow  \
# % Iron Concentrate
# 62.050000                             274.577364
# 62.052219                             297.373000
# 62.053684                             253.345000
# 62.054438                             298.174000
# 62.055014                             295.499000
# ...                                          ...
# 67.630000                             299.995489
# 67.660000                             299.998294
# 67.670000                             349.317211
# 67.990000                             299.905022
# 68.010000                             300.061800
#
#                     Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# % Iron Concentrate
# 62.050000                             275.109861                 569.033331
# 62.052219                             299.907000                 452.648000
# 62.053684                             251.807000                 605.591000
# 62.054438                             298.926000                 450.166000
# 62.055014                             296.715000                 465.839000
# ...                                          ...                        ...
# 67.630000                             299.936183                 500.537472
# 67.660000                             300.866928                 600.451433
# 67.670000                             349.772067                 500.660422
# 67.990000                             299.571333                 400.753367
# 68.010000                             299.814578                 500.424794
#
#                     Flotation Column 02 Level  Flotation Column 03 Level  \
# % Iron Concentrate
# 62.050000                          647.687120                 877.901875
# 62.052219                          464.109000                 870.505128
# 62.053684                          753.845963                 884.255629
# 62.054438                          459.298000                 870.491544
# 62.055014                          466.631000                 872.963834
# ...                                       ...                        ...
# 67.630000                          488.634144                 517.281154
# 67.660000                          599.180372                 600.377139
# 67.670000                          498.751794                 499.952850
# 67.990000                          397.946039                 399.183533
# 68.010000                          499.444217                 499.406578
#
#                     Flotation Column 04 Level  Flotation Column 05 Level  \
# % Iron Concentrate
# 62.050000                          374.896306                 372.729694
# 62.052219                          271.643000                 334.710000
# 62.053684                          430.078000                 380.590000
# 62.054438                          239.322000                 332.128000
# 62.055014                          386.357000                 354.618000
# ...                                       ...                        ...
# 67.630000                          497.519506                 497.175128
# 67.660000                          500.624361                 499.948867
# 67.670000                          353.228433                 350.180106
# 67.990000                          411.818111                 401.818483
# 68.010000                          499.020506                 499.049967
#
#                     Flotation Column 06 Level  Flotation Column 07 Level  \
# % Iron Concentrate
# 62.050000                          392.507081                 371.004833
# 62.052219                          268.534000                 289.385000
# 62.053684                          512.454000                 359.746000
# 62.054438                          327.958000                 322.669000
# 62.055014                          343.276000                 343.150000
# ...                                       ...                        ...
# 67.630000                          503.977833                 499.653206
# 67.660000                          449.454133                 448.839872
# 67.670000                          354.699483                 353.110700
# 67.990000                          398.992378                 405.573106
# 68.010000                          501.710136                 497.050772
#
#                     % Silica Concentrate
# % Iron Concentrate
# 62.050000                       4.100062
# 62.052219                       3.892902
# 62.053684                       4.532482
# 62.054438                       3.892982
# 62.055014                       3.878549
# ...                                  ...
# 67.630000                       1.050000
# 67.660000                       1.410000
# 67.670000                       1.030000
# 67.990000                       1.100000
# 68.010000                       1.380000
#
# [38696 rows x 22 columns]

# %% [markdown]
# Since dataset is very huge .Considering to split the data into train and test

# %%
# deleting date column

# %%
df=df.drop(['date'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
train,test=train_test_split(df,test_size=0.3)

# %%
print('Train size',train.shape)
print('Test size',test.shape)
# Out:
# Train size (515397, 23)
# Test size (220885, 23)

# %%
import missingno
missingno.matrix(train,figsize=(20,5))

# %%
import missingno
missingno.matrix(test,figsize=(20,5))

# %%
plt.figure(figsize=(30,30))
sns.heatmap(train.corr(),annot=True,linewidths=0.3)
plt.show()

# %%
train.columns[-1]
# Out:
# '% Silica Concentrate'

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515397 entries, 178468 to 648954
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   % Iron Feed                   515397 non-null  float64
#  1   % Silica Feed                 515397 non-null  float64
#  2   Starch Flow                   515397 non-null  float64
#  3   Amina Flow                    515397 non-null  float64
#  4   Ore Pulp Flow                 515397 non-null  float64
#  5   Ore Pulp pH                   515397 non-null  float64
#  6   Ore Pulp Density              515397 non-null  float64
#  7   Flotation Column 01 Air Flow  515397 non-null  float64
#  8   Flotation Column 02 Air Flow  515397 non-null  float64
#  9   Flotation Column 03 Air Flow  515397 non-null  float64
#  10  Flotation Column 04 Air Flow  515397 non-null  float64
#  11  Flotation Column 05 Air Flow  515397 non-null  float64
#  12  Flotation Column 06 Air Flow  515397 non-null  float64
#  13  Flotation Column 07 Air Flow  515397 non-null  float64
#  14  Flotation Column 01 Level     515397 non-null  float64
#  15  Flotation Column 02 Level     515397 non-null  float64
#  16  Flotation Column 03 Level     515397 non-null  float64
#  17  Flotation Column 04 Level     515397 non-null  float64
#  18  Flotation Column 05 Level     515397 non-null  float64
#  19  Flotation Column 06 Level     515397 non-null  float64
#  20  Flotation Column 07 Level     515397 non-null  float64
#  21  % Iron Concentrate            515397 non-null  float64
#  22  % Silica Concentrate          515397 non-null  float64
# dtypes: float64(23)
# memory usage: 94.4 MB

# %%
train.describe()
# Out:
#          % Iron Feed  % Silica Feed    Starch Flow     Amina Flow  \
# count  515397.000000  515397.000000  515397.000000  515397.000000
# mean       56.294021      14.653929    2868.134364     488.064789
# std         5.161771       6.813542    1215.774738      91.261174
# min        42.740000       1.310000       0.002026     241.669000
# 25%        52.670000       8.940000    2073.453800     431.662000
# 50%        56.080000      13.850000    3018.260000     504.333000
# 75%        59.720000      19.600000    3726.640000     553.279000
# max        65.780000      33.400000    6300.230000     739.538000
#
#        Ore Pulp Flow    Ore Pulp pH  Ore Pulp Density  \
# count  515397.000000  515397.000000     515397.000000
# mean      397.561351       9.767065          1.680388
# std         9.701435       0.387687          0.069225
# min       376.249000       8.753340          1.519820
# 25%       394.239000       9.526750          1.647290
# 50%       399.235000       9.797110          1.697500
# 75%       402.958000      10.038000          1.728350
# max       418.641000      10.808063          1.853250
#
#        Flotation Column 01 Air Flow  Flotation Column 02 Air Flow  \
# count                 515397.000000                 515397.000000
# mean                     280.082055                    277.094933
# std                       29.666182                     30.174351
# min                      175.558000                    175.156000
# 25%                      250.274000                    250.448000
# 50%                      299.339000                    296.192000
# 75%                      300.147000                    300.675000
# max                      373.549000                    375.992000
#
#        Flotation Column 03 Air Flow  ...  Flotation Column 07 Air Flow  \
# count                 515397.000000  ...                 515397.000000
# mean                     281.022480  ...                    290.701262
# std                       28.594888  ...                     28.699742
# min                      176.471917  ...                    185.981000
# 25%                      250.840000  ...                    255.897151
# 50%                      298.689000  ...                    298.997000
# 75%                      300.386000  ...                    301.904000
# max                      363.122000  ...                    371.593000
#
#        Flotation Column 01 Level  Flotation Column 02 Level  \
# count              515397.000000              515397.000000
# mean                  520.345097                 522.557643
# std                   131.163250                 128.321188
# min                   149.218000                 210.752000
# 25%                   417.056000                 441.843000
# 50%                   491.876000                 495.861000
# 75%                   594.233000                 595.264000
# max                   862.274000                 828.919000
#
#        Flotation Column 03 Level  Flotation Column 04 Level  \
# count              515397.000000              515397.000000
# mean                  531.472260                 420.295078
# std                   150.999326                  91.817500
# min                   126.255000                 162.201000
# 25%                   411.317000                 356.705000
# 50%                   494.323000                 411.922000
# 75%                   601.383000                 485.534000
# max                   886.822000                 680.359000
#
#        Flotation Column 05 Level  Flotation Column 06 Level  \
# count              515397.000000              515397.000000
# mean                  425.229394                 430.063089
# std                    84.539556                  89.924362
# min                   166.991000                 155.841000
# 25%                   357.655000                 358.568000
# 50%                   408.862000                 424.805000
# 75%                   484.229000                 492.870000
# max                   675.644000                 698.861000
#
#        Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# count              515397.000000       515397.000000         515397.000000
# mean                  421.045265           65.048401              2.327339
# std                    84.910577            1.119643              1.125564
# min                   175.377000           62.050000              0.600000
# 25%                   356.770000           64.361362              1.440000
# 50%                   411.071000           65.210000              2.000000
# 75%                   476.281000           65.860000              3.010000
# max                   659.902000           68.010000              5.530000
#
# [8 rows x 23 columns]

# %% [markdown]
# ## % for Iron Concentration

# %%
# Deleting date columns and % Iron Concentration
y=train['% Iron Concentrate']
X=train.drop(['% Silica Concentrate','% Iron Concentrate'],axis=1)

# %% [markdown]
# ## 1. Base Model

# %%
import statsmodels.api as sm
xc=sm.add_constant(X)
xc=xc.drop(['Flotation Column 07 Air Flow'],axis=1)
model=sm.OLS(y,xc).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     % Iron Concentrate   R-squared:                       0.140
# Model:                            OLS   Adj. R-squared:                  0.140
# Method:                 Least Squares   F-statistic:                     4184.
# Date:                Sat, 23 May 2020   Prob (F-statistic):               0.00
# Time:                        09:32:40   Log-Likelihood:            -7.5079e+05
# No. Observations:              515397   AIC:                         1.502e+06
# Df Residuals:                  515376   BIC:                         1.502e+06
# Df Model:                          20
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           52.7102      0.290    181.957      0.000      52.142      53.278
# % Iron Feed                      0.0371      0.001     30.145      0.000       0.035       0.040
# % Silica Feed                    0.0273      0.001     29.398      0.000       0.025       0.029
# Starch Flow                   2.699e-05   1.34e-06     20.180      0.000    2.44e-05    2.96e-05
# Amina Flow                      -0.0033   2.33e-05   -140.721      0.000      -0.003      -0.003
# Ore Pulp Flow                    0.0114      0.000     68.504      0.000       0.011       0.012
# Ore Pulp pH                      0.4772      0.004    117.401      0.000       0.469       0.485
# Ore Pulp Density                 2.6706      0.030     90.208      0.000       2.613       2.729
# Flotation Column 01 Air Flow     0.0047      0.000     27.730      0.000       0.004       0.005
# Flotation Column 02 Air Flow    -0.0031   9.99e-05    -31.046      0.000      -0.003      -0.003
# Flotation Column 03 Air Flow     0.0058      0.000     31.118      0.000       0.005       0.006
# Flotation Column 04 Air Flow    -0.0401      0.001    -56.795      0.000      -0.041      -0.039
# Flotation Column 05 Air Flow     0.0265      0.000     60.574      0.000       0.026       0.027
# Flotation Column 06 Air Flow    -0.0027   7.12e-05    -37.556      0.000      -0.003      -0.003
# Flotation Column 01 Level       -0.0001   1.88e-05     -6.092      0.000      -0.000   -7.78e-05
# Flotation Column 02 Level       -0.0001   1.73e-05     -8.117      0.000      -0.000      -0.000
# Flotation Column 03 Level       -0.0004   1.49e-05    -23.717      0.000      -0.000      -0.000
# Flotation Column 04 Level        0.0002   2.26e-05      9.766      0.000       0.000       0.000
# Flotation Column 05 Level        0.0013   2.82e-05     45.277      0.000       0.001       0.001
# Flotation Column 06 Level       -0.0004   2.17e-05    -16.693      0.000      -0.000      -0.000
# Flotation Column 07 Level        0.0006   2.66e-05     24.265      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                    17398.154   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19231.167
# Skew:                          -0.473   Prob(JB):                         0.00
# Kurtosis:                       3.016   Cond. No.                     6.89e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.89e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
residuals=model.resid
sns.distplot(residuals)

# %%
import scipy.stats as stats
stats.probplot(residuals,plot=plt)
plt.show()

# %% [markdown]
# ### Autocorrelation Check

# %%
import statsmodels.tsa.api as smt
acf=smt.graphics.plot_acf(residuals,lags=40)
acf.show()
# Out:
# C:\Users\pravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Multicollinearity Check

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
pd.DataFrame({'vif':vif},index=X.columns).T
# Out:
#      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  Ore Pulp Flow  \
# vif  2155.026091     100.709121     8.282469   63.330357    2009.088594
#
#      Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# vif   758.547642       1121.984043                   1099.055543
#
#      Flotation Column 02 Air Flow  Flotation Column 03 Air Flow  ...  \
# vif                    371.129742                   1338.540637  ...
#
#      Flotation Column 05 Air Flow  Flotation Column 06 Air Flow  \
# vif                   5716.856963                    406.835982
#
#      Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# vif                     431.41375                  48.749231
#
#      Flotation Column 02 Level  Flotation Column 03 Level  \
# vif                   41.33135                   32.57403
#
#      Flotation Column 04 Level  Flotation Column 05 Level  \
# vif                  45.316806                  71.139949
#
#      Flotation Column 06 Level  Flotation Column 07 Level
# vif                  42.918971                  62.416831
#
# [1 rows x 21 columns]

# %%
from sklearn import metrics

# %% [markdown]
# ### 2.Linear Regression -ML

# %%
y=train['% Iron Concentrate']
X=train.drop(['% Silica Concentrate','% Iron Concentrate'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                        test_size=0.30, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train_pred=lr.predict(X_train)
print ("feature_importances:",lr.intercept_)
print ("n_coefficients:         ",lr.coef_)
# Out:
# feature_importances: 53.4492483034445
# n_coefficients:          [ 3.66485355e-02  2.70946542e-02  2.78932988e-05 -3.27186785e-03
#   1.12395664e-02  4.70561512e-01  2.67519782e+00  4.66037698e-03
#  -3.15520876e-03  5.81834505e-03 -4.25573353e-02  2.66300803e-02
#  -3.73873625e-03  1.55335809e-03 -1.11691083e-04 -1.34730098e-04
#  -3.58794530e-04  2.14607007e-04  1.25120374e-03 -3.77886671e-04
#   6.80977492e-04]

# %%
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.14024384075095864
# L1 Mean absolute Error:  0.8258928619636658
# L2 Mean square Error:  1.0767927263445372
# L2 RMSE:  1.037686236944741

# %%
y_test_pred=lr.predict(X_test)

# %%
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.13953742288101412
# L1 Mean absolute Error:  0.8282070692592657
# L2 Mean square Error:  1.0809935301956353
# L2 RMSE:  1.0397083870949755

# %% [markdown]
# ## 3. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### Changing max depth

# %%
train_accuracy=[]
test_accuracy=[]

for depth in range(5,20):
    dt_model=DecisionTreeRegressor(max_depth=depth,random_state=42)
    dt_model.fit(X_train,y_train)
    train_accuracy.append(dt_model.score(X_train,y_train))
    test_accuracy.append(dt_model.score(X_test,y_test))

# %%
frame=pd.DataFrame({'max_depth':range(5,20),'train_accuracy':train_accuracy,'test_accuracy':test_accuracy})
print(frame)
# Out:
#     max_depth  train_accuracy  test_accuracy
# 0           5        0.172766       0.175373
# 1           6        0.222135       0.222736
# 2           7        0.266359       0.267150
# 3           8        0.324422       0.323086
# 4           9        0.376945       0.374984
# 5          10        0.435932       0.429163
# 6          11        0.493082       0.483320
# 7          12        0.554790       0.541603
# 8          13        0.612444       0.594946
# 9          14        0.668051       0.646297
# 10         15        0.722050       0.693626
# 11         16        0.764865       0.729158
# 12         17        0.804506       0.758012
# 13         18        0.839875       0.785543
# 14         19        0.870490       0.806202

# %%
plt.figure(figsize=(13,6))
plt.plot(frame['max_depth'],frame['train_accuracy'],marker='o')
plt.plot(frame['max_depth'],frame['test_accuracy'],marker='o')
plt.xlabel('Depth of Tree')
plt.ylabel('Accuracy Performance')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
print ("feature_importances:",dtr.feature_importances_)
print ("Best params: \n        ",dtr.get_params)
print('n feature',dtr.n_features_)
print(dtr.n_outputs_)
# Out:
# feature_importances: [0.12432635 0.12376198 0.04380089 0.06990326 0.02324451 0.11934527
#  0.08526884 0.02794871 0.0158615  0.01305599 0.06962829 0.0495984
#  0.01694571 0.009981   0.03382767 0.03191584 0.05544307 0.01066361
#  0.05385088 0.01459376 0.00703447]
# Best params:
#          <bound method BaseEstimator.get_params of DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')>
# n feature 21
# 1

# %%
y_train_pred=dtr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.9999993187453053
# L1 Mean absolute Error:  5.8610231649134836e-06
# L2 Mean square Error:  8.532304097485549e-07
# L2 RMSE:  0.0009237047199990671

# %%
y_test_pred=dtr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.8693679629415398
# L1 Mean absolute Error:  0.11112617215434413
# L2 Mean square Error:  0.16411217716089577
# L2 RMSE:  0.40510761182788924

# %% [markdown]
# ## 4. Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
print ("feature_importances:",rfr.feature_importances_)
print ("n_coefficients:         ",rfr.get_params)
print('n feature',rfr.n_features_)
print(rfr.n_outputs_)
# Out:
# feature_importances: [0.12325624 0.12251018 0.04427909 0.06684724 0.02268063 0.11722963
#  0.08036081 0.02642638 0.01652994 0.01639392 0.07008823 0.05341417
#  0.01780714 0.00913983 0.03693585 0.03346352 0.05470532 0.01057796
#  0.05402387 0.01508698 0.00824308]
# n_coefficients:          <bound method BaseEstimator.get_params of RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)>
# n feature 21
# 1

# %%
y_train_pred=rfr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.9924611294344605
# L1 Mean absolute Error:  0.04571094635952338
# L2 Mean square Error:  0.00944198061566246
# L2 RMSE:  0.09716985445940762

# %%
y_test_pred=rfr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.9479428731965366
# L1 Mean absolute Error:  0.12111630843140798
# L2 Mean square Error:  0.0653990292797315
# L2 RMSE:  0.25573233913553345

# %% [markdown]
# ## Considering Random Forest Regressor Base Model as the final model. Implementing the model in the test data set

# %%
test
# Out:
#         % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  Ore Pulp Flow  \
# 198802        56.65          14.83  3073.280000  495.945000     398.943000
# 139786        52.75          19.18  2569.980000  601.807000     396.776000
# 208684        52.61          20.24   798.506778  311.927881     404.015278
# 120336        57.18          12.01  2403.090000  518.188000     396.838000
# 210954        52.61          20.24  2626.770000  531.737000     400.897000
# ...             ...            ...          ...         ...            ...
# 106857        49.93          22.17  2156.410000  515.451000     402.291000
# 326083        64.03           6.26   642.540512  595.601000     398.487000
# 562242        57.46          10.80  4010.760000  545.435000     387.305000
# 615297        48.81          25.31  4031.250000  485.055000     377.026000
# 465821        52.30          17.83  3408.710000  476.483000     394.759000
#
#         Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 198802      9.72470          1.711500                    250.173000
# 139786      9.94775          1.720780                    299.487000
# 208684      8.95187          1.520737                    194.308013
# 120336      9.68920          1.699470                    249.140000
# 210954      9.55865          1.723350                    250.092000
# ...             ...               ...                           ...
# 106857      9.36467          1.745640                    250.040000
# 326083      9.68994          1.718610                    299.359000
# 562242     10.28620          1.685720                    298.248000
# 615297     10.36050          1.685880                    298.874000
# 465821     10.52170          1.694680                    298.798000
#
#         Flotation Column 02 Air Flow  Flotation Column 03 Air Flow  ...  \
# 198802                     253.59100                    249.163000  ...
# 139786                     303.71000                    300.207000  ...
# 208684                     201.32904                    192.377901  ...
# 120336                     251.97000                    250.681000  ...
# 210954                     248.28800                    248.248000  ...
# ...                              ...                           ...  ...
# 106857                     245.77900                    251.202000  ...
# 326083                     251.78900                    300.166000  ...
# 562242                     250.15900                    300.146000  ...
# 615297                     252.24600                    297.052000  ...
# 465821                     296.55800                    299.402000  ...
#
#         Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# 198802                    304.618000                 450.025000
# 139786                    300.838000                 385.685000
# 208684                    212.150577                 798.308475
# 120336                    252.377000                 582.494000
# 210954                    307.349000                 452.741000
# ...                              ...                        ...
# 106857                    250.751000                 607.525000
# 326083                    301.555000                 384.332000
# 562242                    298.389000                 432.407000
# 615297                    300.751000                 554.853000
# 465821                    293.276000                 504.290000
#
#         Flotation Column 02 Level  Flotation Column 03 Level  \
# 198802                 430.703000                 447.604000
# 139786                 414.219000                 401.328000
# 208684                 655.751644                 844.170383
# 120336                 616.150000                 657.508000
# 210954                 447.118000                 374.651000
# ...                           ...                        ...
# 106857                 614.108000                 586.080000
# 326083                 493.383000                 346.890000
# 562242                 578.471000                 425.511000
# 615297                 549.296000                 546.160000
# 465821                 510.186000                 503.444000
#
#         Flotation Column 04 Level  Flotation Column 05 Level  \
# 198802                 368.668000                 350.987000
# 139786                 367.970000                 393.338000
# 208684                 650.398806                 341.965173
# 120336                 246.259000                 393.021000
# 210954                 365.916000                 348.651000
# ...                           ...                        ...
# 106857                 386.413000                 370.477000
# 326083                 216.279000                 304.621000
# 562242                 355.859000                 304.582000
# 615297                 494.840000                 500.867000
# 465821                 513.457000                 493.286000
#
#         Flotation Column 06 Level  Flotation Column 07 Level  \
# 198802                  323.42100                 356.078000
# 139786                  353.34700                 397.897000
# 208684                  682.81371                 346.271516
# 120336                  383.19500                 408.374000
# 210954                  353.95700                 365.070000
# ...                           ...                        ...
# 106857                  437.68800                 414.104000
# 326083                  320.34800                 182.227800
# 562242                  347.51600                 394.187000
# 615297                  491.89500                 500.100000
# 465821                  450.24200                 461.674000
#
#         % Iron Concentrate  % Silica Concentrate
# 198802           63.530000              3.540000
# 139786           62.201373              3.898754
# 208684           62.870000              5.030000
# 120336           62.840000              3.572012
# 210954           66.330000              1.310000
# ...                    ...                   ...
# 106857           63.560000              3.270000
# 326083           65.020000              1.740000
# 562242           62.184309              4.880111
# 615297           65.610000              0.740000
# 465821           66.160000              1.040000
#
# [220885 rows x 23 columns]

# %%
expected_output=train['% Iron Concentrate']
expected_input=train.drop(['% Iron Concentrate','% Silica Concentrate'],axis=1)

# %%
y_pred=rfr.predict(expected_input)

# %%
print('R2 of Output: ', metrics.r2_score(expected_output,y_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(expected_output,y_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(expected_output,y_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(expected_output,y_pred)))
# Out:
# R2 of Output:  0.979076888925551
# L1 Mean absolute Error:  0.06833268665594498
# L2 Mean square Error:  0.02622919292857534
# L2 RMSE:  0.16195429271425732
