# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('../DATA/MiningProcess_Flotation_Plant_Database.csv',decimal=',').drop_duplicates()
df.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1  2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2  2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3  2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4  2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
#    Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# 0                       253.235  ...                       250.884
# 1                       250.532  ...                       248.994
# 2                       247.874  ...                       248.071
# 3                       254.487  ...                       251.147
# 4                       252.136  ...                       248.928
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    457.396                    432.962
# 1                    451.891                    429.560
# 2                    451.240                    468.927
# 3                    452.441                    458.165
# 4                    452.441                    452.900
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    424.954                    443.558
# 1                    432.939                    448.086
# 2                    434.610                    449.688
# 3                    442.865                    446.210
# 4                    450.523                    453.670
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                    502.255                    446.370
# 1                    496.363                    445.922
# 2                    484.411                    447.826
# 3                    471.411                    437.690
# 4                    462.598                    443.682
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                    523.344               66.91                  1.31
# 1                    498.075               66.91                  1.31
# 2                    458.567               66.91                  1.31
# 3                    427.669               66.91                  1.31
# 4                    425.679               66.91                  1.31
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (736282, 24)

# %%
df.columns
# Out:
# Index(['date', '% Iron Feed', '% Silica Feed', 'Starch Flow', 'Amina Flow',
#        'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density',
#        'Flotation Column 01 Air Flow', 'Flotation Column 02 Air Flow',
#        'Flotation Column 03 Air Flow', 'Flotation Column 04 Air Flow',
#        'Flotation Column 05 Air Flow', 'Flotation Column 06 Air Flow',
#        'Flotation Column 07 Air Flow', 'Flotation Column 01 Level',
#        'Flotation Column 02 Level', 'Flotation Column 03 Level',
#        'Flotation Column 04 Level', 'Flotation Column 05 Level',
#        'Flotation Column 06 Level', 'Flotation Column 07 Level',
#        '% Iron Concentrate', '% Silica Concentrate'],
#       dtype='object')

# %% [markdown]
# # Date in Mining Ores

# %%
df.groupby(['date'])

# %%
plt.figure(figsize=(30,10))
df.groupby(['date']).mean()['% Silica Concentrate'].plot()
plt.show()

# %%
plt.figure(figsize=(30,10))
df.groupby(['date']).mean()['% Iron Concentrate'].plot()
plt.show()

# %% [markdown]
# ### % Silica Concentrate

# %%
plt.hist(df['% Silica Concentrate'],bins=12)
# Out:
# (array([ 16308., 162245., 142906., 121603.,  69765.,  44794.,  46322.,
#          39089.,  30005.,  24129.,  27574.,  11542.]),
#  array([0.6       , 1.01083333, 1.42166667, 1.8325    , 2.24333333,
#         2.65416667, 3.065     , 3.47583333, 3.88666667, 4.2975    ,
#         4.70833333, 5.11916667, 5.53      ]),
#  <a list of 12 Patch objects>)

# %%
df.groupby(['% Silica Concentrate']).mean()
# Out:
#                       % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# % Silica Concentrate
# 0.600000                    48.81          25.31  3507.572389  430.847311
# 0.660000                    48.81          25.31  2185.361279  419.244482
# 0.740000                    48.81          25.31  3890.823333  458.506367
# 0.750000                    48.81          25.31  2975.124778  393.377690
# 0.770000                    56.45          13.57  2169.709250  505.566494
# ...                           ...            ...          ...         ...
# 5.529187                    57.46          10.80  4851.520000  656.820000
# 5.529390                    57.46          10.80  4836.140000  624.736000
# 5.529593                    57.46          10.80  4824.430000  642.565000
# 5.529797                    57.46          10.80  4801.680000  637.808000
# 5.530000                    49.80          22.34  3414.716557  584.756947
#
#                       Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# % Silica Concentrate
# 0.600000                 379.343667    10.291061          1.700894
# 0.660000                 381.502420     9.469579          1.684721
# 0.740000                 381.110714    10.395589          1.687037
# 0.750000                 381.802851    10.032917          1.691862
# 0.770000                 399.946089     9.599748          1.740165
# ...                             ...          ...               ...
# 5.529187                 401.131000    10.341000          1.714080
# 5.529390                 401.029000    10.340400          1.713990
# 5.529593                 403.687000    10.339800          1.713900
# 5.529797                 405.080000    10.339700          1.713810
# 5.530000                 400.118455     9.819079          1.707561
#
#                       Flotation Column 01 Air Flow  \
# % Silica Concentrate
# 0.600000                                299.788706
# 0.660000                                299.946906
# 0.740000                                299.857589
# 0.750000                                299.739750
# 0.770000                                250.016756
# ...                                            ...
# 5.529187                                300.249000
# 5.529390                                299.869000
# 5.529593                                299.937000
# 5.529797                                300.528000
# 5.530000                                299.795376
#
#                       Flotation Column 02 Air Flow  \
# % Silica Concentrate
# 0.600000                                249.868783
# 0.660000                                300.510120
# 0.740000                                249.901839
# 0.750000                                250.036283
# 0.770000                                249.942567
# ...                                            ...
# 5.529187                                292.510000
# 5.529390                                298.185000
# 5.529593                                298.919000
# 5.529797                                292.035000
# 5.530000                                299.886991
#
#                       Flotation Column 03 Air Flow  ...  \
# % Silica Concentrate                                ...
# 0.600000                                299.859722  ...
# 0.660000                                299.952711  ...
# 0.740000                                299.920178  ...
# 0.750000                                299.923211  ...
# 0.770000                                250.024272  ...
# ...                                            ...  ...
# 5.529187                                297.188000  ...
# 5.529390                                298.148000  ...
# 5.529593                                300.501000  ...
# 5.529797                                302.124000  ...
# 5.530000                                299.883157  ...
#
#                       Flotation Column 06 Air Flow  \
# % Silica Concentrate
# 0.600000                                299.580378
# 0.660000                                249.966511
# 0.740000                                299.991356
# 0.750000                                299.779978
# 0.770000                                250.022533
# ...                                            ...
# 5.529187                                291.279000
# 5.529390                                298.651000
# 5.529593                                308.092000
# 5.529797                                299.051000
# 5.530000                                299.776535
#
#                       Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# % Silica Concentrate
# 0.600000                                287.760011                 549.482956
# 0.660000                                250.045646                 553.295064
# 0.740000                                299.922417                 550.379206
# 0.750000                                250.008144                 556.294867
# 0.770000                                250.085961                 603.269472
# ...                                            ...                        ...
# 5.529187                                302.016000                 400.282000
# 5.529390                                299.579000                 373.471000
# 5.529593                                298.666000                 376.051000
# 5.529797                                299.060000                 444.451000
# 5.530000                                299.626998                 466.203320
#
#                       Flotation Column 02 Level  Flotation Column 03 Level  \
# % Silica Concentrate
# 0.600000                             548.923283                 549.972750
# 0.660000                             504.124909                 750.439797
# 0.740000                             549.588667                 549.821300
# 0.750000                             553.436206                 560.644808
# 0.770000                             600.161144                 601.072817
# ...                                         ...                        ...
# 5.529187                             440.689000                 390.901000
# 5.529390                             396.158000                 396.315000
# 5.529593                             383.141000                 394.713000
# 5.529797                             252.555000                 392.063000
# 5.530000                             470.200318                 543.103345
#
#                       Flotation Column 04 Level  Flotation Column 05 Level  \
# % Silica Concentrate
# 0.600000                             516.092072                 517.980733
# 0.660000                             454.544115                 453.474052
# 0.740000                             498.237644                 499.867883
# 0.750000                             562.173389                 550.175139
# 0.770000                             449.567033                 449.980850
# ...                                         ...                        ...
# 5.529187                             314.406000                 339.873000
# 5.529390                             356.765000                 352.086000
# 5.529593                             394.682000                 370.609000
# 5.529797                             334.993000                 340.588000
# 5.530000                             397.303592                 400.015793
#
#                       Flotation Column 06 Level  Flotation Column 07 Level  \
# % Silica Concentrate
# 0.600000                             511.288872                 513.563067
# 0.660000                             500.682550                 502.348081
# 0.740000                             499.730194                 498.209325
# 0.750000                             552.597044                 551.615594
# 0.770000                             447.103056                 450.250956
# ...                                         ...                        ...
# 5.529187                             353.915000                 371.580000
# 5.529390                             399.213000                 359.175000
# 5.529593                             452.038000                 368.375000
# 5.529797                             427.846000                 343.693000
# 5.530000                             401.980517                 399.966089
#
#                       % Iron Concentrate
# % Silica Concentrate
# 0.600000                       66.570000
# 0.660000                       65.120000
# 0.740000                       65.610000
# 0.750000                       66.780000
# 0.770000                       66.900000
# ...                                  ...
# 5.529187                       62.360000
# 5.529390                       62.360000
# 5.529593                       62.360000
# 5.529797                       62.360000
# 5.530000                       63.658947
#
# [55569 rows x 22 columns]

# %% [markdown]
# ### % Iron Concentrate

# %%
plt.hist(df['% Iron Concentrate'],bins=12)
# Out:
# (array([ 19107.,  32491.,  32278.,  53279.,  73268., 110012., 149995.,
#         119093.,  98786.,  36633.,  10080.,   1260.]),
#  array([62.05      , 62.54666667, 63.04333333, 63.54      , 64.03666667,
#         64.53333333, 65.03      , 65.52666667, 66.02333333, 66.52      ,
#         67.01666667, 67.51333333, 68.01      ]),
#  <a list of 12 Patch objects>)

# %%
df.groupby(['% Iron Concentrate']).mean()
# Out:
#                     % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# % Iron Concentrate
# 62.050000                 57.08          13.35  2234.233667  542.608150
# 62.052219                 59.78           9.29  2179.080000  559.878000
# 62.053684                 54.38          17.41  2152.340000  576.782000
# 62.054438                 59.78           9.29  2176.350000  563.970000
# 62.055014                 59.78           9.29  2404.300000  580.116000
# ...                         ...            ...          ...         ...
# 67.630000                 64.03           6.26  4052.176444  450.924417
# 67.660000                 49.35          24.90  3077.049500  377.148094
# 67.670000                 48.81          25.31  3641.604167  404.219844
# 67.990000                 55.78          12.85  2588.626106  431.233456
# 68.010000                 47.79          27.08  4322.071578  517.330928
#
#                     Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# % Iron Concentrate
# 62.050000              400.167157     9.764361          1.766480
# 62.052219              396.816000     9.788190          1.771370
# 62.053684              404.297000     9.750870          1.783270
# 62.054438              397.320000     9.789000          1.770600
# 62.055014              399.114000     9.998960          1.783490
# ...                           ...          ...               ...
# 67.630000              400.162194    10.158235          1.594675
# 67.660000              400.064061    10.244143          1.658189
# 67.670000              380.739842     9.933260          1.704377
# 67.990000              400.952456    10.693607          1.543400
# 68.010000              399.700861    10.463737          1.732864
#
#                     Flotation Column 01 Air Flow  \
# % Iron Concentrate
# 62.050000                             275.036800
# 62.052219                             300.484000
# 62.053684                             250.269000
# 62.054438                             300.526000
# 62.055014                             299.487000
# ...                                          ...
# 67.630000                             299.930939
# 67.660000                             249.998239
# 67.670000                             299.911356
# 67.990000                             299.981528
# 68.010000                             299.859072
#
#                     Flotation Column 02 Air Flow  \
# % Iron Concentrate
# 62.050000                             275.150456
# 62.052219                             303.163000
# 62.053684                             257.080000
# 62.054438                             302.561000
# 62.055014                             306.062000
# ...                                          ...
# 67.630000                             299.651872
# 67.660000                             249.948056
# 67.670000                             298.836394
# 67.990000                             300.051550
# 68.010000                             299.737372
#
#                     Flotation Column 03 Air Flow  ...  \
# % Iron Concentrate                                ...
# 62.050000                             274.954469  ...
# 62.052219                             302.548000  ...
# 62.053684                             251.587000  ...
# 62.054438                             301.143000  ...
# 62.055014                             301.820000  ...
# ...                                          ...  ...
# 67.630000                             299.908261  ...
# 67.660000                             250.111900  ...
# 67.670000                             299.982222  ...
# 67.990000                             299.870878  ...
# 68.010000                             299.957161  ...
#
#                     Flotation Column 06 Air Flow  \
# % Iron Concentrate
# 62.050000                             274.577364
# 62.052219                             297.373000
# 62.053684                             253.345000
# 62.054438                             298.174000
# 62.055014                             295.499000
# ...                                          ...
# 67.630000                             299.995489
# 67.660000                             299.998294
# 67.670000                             349.317211
# 67.990000                             299.905022
# 68.010000                             300.061800
#
#                     Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# % Iron Concentrate
# 62.050000                             275.109861                 569.033331
# 62.052219                             299.907000                 452.648000
# 62.053684                             251.807000                 605.591000
# 62.054438                             298.926000                 450.166000
# 62.055014                             296.715000                 465.839000
# ...                                          ...                        ...
# 67.630000                             299.936183                 500.537472
# 67.660000                             300.866928                 600.451433
# 67.670000                             349.772067                 500.660422
# 67.990000                             299.571333                 400.753367
# 68.010000                             299.814578                 500.424794
#
#                     Flotation Column 02 Level  Flotation Column 03 Level  \
# % Iron Concentrate
# 62.050000                          647.687120                 877.901875
# 62.052219                          464.109000                 870.505128
# 62.053684                          753.845963                 884.255629
# 62.054438                          459.298000                 870.491544
# 62.055014                          466.631000                 872.963834
# ...                                       ...                        ...
# 67.630000                          488.634144                 517.281154
# 67.660000                          599.180372                 600.377139
# 67.670000                          498.751794                 499.952850
# 67.990000                          397.946039                 399.183533
# 68.010000                          499.444217                 499.406578
#
#                     Flotation Column 04 Level  Flotation Column 05 Level  \
# % Iron Concentrate
# 62.050000                          374.896306                 372.729694
# 62.052219                          271.643000                 334.710000
# 62.053684                          430.078000                 380.590000
# 62.054438                          239.322000                 332.128000
# 62.055014                          386.357000                 354.618000
# ...                                       ...                        ...
# 67.630000                          497.519506                 497.175128
# 67.660000                          500.624361                 499.948867
# 67.670000                          353.228433                 350.180106
# 67.990000                          411.818111                 401.818483
# 68.010000                          499.020506                 499.049967
#
#                     Flotation Column 06 Level  Flotation Column 07 Level  \
# % Iron Concentrate
# 62.050000                          392.507081                 371.004833
# 62.052219                          268.534000                 289.385000
# 62.053684                          512.454000                 359.746000
# 62.054438                          327.958000                 322.669000
# 62.055014                          343.276000                 343.150000
# ...                                       ...                        ...
# 67.630000                          503.977833                 499.653206
# 67.660000                          449.454133                 448.839872
# 67.670000                          354.699483                 353.110700
# 67.990000                          398.992378                 405.573106
# 68.010000                          501.710136                 497.050772
#
#                     % Silica Concentrate
# % Iron Concentrate
# 62.050000                       4.100062
# 62.052219                       3.892902
# 62.053684                       4.532482
# 62.054438                       3.892982
# 62.055014                       3.878549
# ...                                  ...
# 67.630000                       1.050000
# 67.660000                       1.410000
# 67.670000                       1.030000
# 67.990000                       1.100000
# 68.010000                       1.380000
#
# [38696 rows x 22 columns]

# %% [markdown]
# Since dataset is very huge .Considering to split the data into train and test

# %%
# deleting date column

# %%
df=df.drop(['date'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
train,test=train_test_split(df,test_size=0.3)

# %%
print('Train size',train.shape)
print('Test size',test.shape)
# Out:
# Train size (515397, 23)
# Test size (220885, 23)

# %%
import missingno
missingno.matrix(train,figsize=(20,5))

# %%
import missingno
missingno.matrix(test,figsize=(20,5))

# %%
plt.figure(figsize=(30,30))
sns.heatmap(train.corr(),annot=True,linewidths=0.3)
plt.show()

# %%
train.columns[-1]
# Out:
# '% Silica Concentrate'

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515397 entries, 426869 to 484377
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   % Iron Feed                   515397 non-null  float64
#  1   % Silica Feed                 515397 non-null  float64
#  2   Starch Flow                   515397 non-null  float64
#  3   Amina Flow                    515397 non-null  float64
#  4   Ore Pulp Flow                 515397 non-null  float64
#  5   Ore Pulp pH                   515397 non-null  float64
#  6   Ore Pulp Density              515397 non-null  float64
#  7   Flotation Column 01 Air Flow  515397 non-null  float64
#  8   Flotation Column 02 Air Flow  515397 non-null  float64
#  9   Flotation Column 03 Air Flow  515397 non-null  float64
#  10  Flotation Column 04 Air Flow  515397 non-null  float64
#  11  Flotation Column 05 Air Flow  515397 non-null  float64
#  12  Flotation Column 06 Air Flow  515397 non-null  float64
#  13  Flotation Column 07 Air Flow  515397 non-null  float64
#  14  Flotation Column 01 Level     515397 non-null  float64
#  15  Flotation Column 02 Level     515397 non-null  float64
#  16  Flotation Column 03 Level     515397 non-null  float64
#  17  Flotation Column 04 Level     515397 non-null  float64
#  18  Flotation Column 05 Level     515397 non-null  float64
#  19  Flotation Column 06 Level     515397 non-null  float64
#  20  Flotation Column 07 Level     515397 non-null  float64
#  21  % Iron Concentrate            515397 non-null  float64
#  22  % Silica Concentrate          515397 non-null  float64
# dtypes: float64(23)
# memory usage: 94.4 MB

# %%
train.describe()
# Out:
#          % Iron Feed  % Silica Feed    Starch Flow     Amina Flow  \
# count  515397.000000  515397.000000  515397.000000  515397.000000
# mean       56.291504      14.656625    2868.486582     488.228762
# std         5.161306       6.813255    1217.139585      91.257097
# min        42.740000       1.310000       0.002026     241.688000
# 25%        52.670000       8.940000    2074.670000     431.938000
# 50%        56.080000      13.850000    3020.515500     504.399000
# 75%        59.720000      19.600000    3729.450000     553.486000
# max        65.780000      33.400000    6300.230000     739.504000
#
#        Ore Pulp Flow    Ore Pulp pH  Ore Pulp Density  \
# count  515397.000000  515397.000000     515397.000000
# mean      397.560446       9.767362          1.680511
# std         9.707651       0.387005          0.069189
# min       376.250000       8.753340          1.519820
# 25%       394.235000       9.527230          1.647560
# 50%       399.227000       9.797450          1.697640
# 75%       402.961000      10.038100          1.728440
# max       418.641000      10.808100          1.853250
#
#        Flotation Column 01 Air Flow  Flotation Column 02 Air Flow  \
# count                 515397.000000                 515397.000000
# mean                     280.104832                    277.104169
# std                       29.649171                     30.168259
# min                      175.510000                    175.156000
# 25%                      250.279000                    250.447000
# 50%                      299.340000                    296.199000
# 75%                      300.149000                    300.688000
# max                      372.684000                    375.965000
#
#        Flotation Column 03 Air Flow  ...  Flotation Column 07 Air Flow  \
# count                 515397.000000  ...                 515397.000000
# mean                     281.039096  ...                    290.716658
# std                       28.578453  ...                     28.715404
# min                      176.469000  ...                    185.962000
# 25%                      250.840000  ...                    255.851000
# 50%                      298.691000  ...                    298.995000
# 75%                      300.385000  ...                    301.909000
# max                      363.122000  ...                    371.592000
#
#        Flotation Column 01 Level  Flotation Column 02 Level  \
# count              515397.000000              515397.000000
# mean                  520.192405                 522.568627
# std                   131.174752                 128.279428
# min                   149.218000                 210.752000
# 25%                   416.779000                 441.797000
# 50%                   491.707000                 495.804000
# 75%                   594.089000                 595.284000
# max                   862.274000                 828.919000
#
#        Flotation Column 03 Level  Flotation Column 04 Level  \
# count              515397.000000              515397.000000
# mean                  531.353169                 420.183496
# std                   151.074798                  91.721118
# min                   126.255000                 162.201000
# 25%                   411.128000                 356.640000
# 50%                   494.189000                 411.749000
# 75%                   601.365000                 485.282000
# max                   886.822000                 680.359000
#
#        Flotation Column 05 Level  Flotation Column 06 Level  \
# count              515397.000000              515397.000000
# mean                  425.111835                 429.938852
# std                    84.470085                  89.933126
# min                   166.991000                 156.004000
# 25%                   357.677000                 358.438000
# 50%                   408.635000                 424.388000
# 75%                   484.031000                 492.765000
# max                   675.644000                 698.861000
#
#        Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# count              515397.000000       515397.000000         515397.000000
# mean                  420.918586           65.049026              2.327523
# std                    84.832221            1.118784              1.125835
# min                   175.349000           62.050000              0.600000
# 25%                   356.848000           64.370000              1.440000
# 50%                   411.012000           65.210000              2.000000
# 75%                   476.072000           65.860000              3.010000
# max                   659.902000           68.010000              5.530000
#
# [8 rows x 23 columns]

# %% [markdown]
# ## % for Silicon Concentration

# %%
import statsmodels.api as sm

# %%
# Deleting date columns and % Iron Concentration
y=train['% Silica Concentrate']
X=train.drop(['% Silica Concentrate'],axis=1)

# %%
# Backward Elimination
cols=list(X.columns)
pmax=1
while len(cols)>0:
    p=[]
    C=X[cols]
    xc=sm.add_constant(C)
    model=sm.OLS(y,xc).fit()
    p=pd.Series(model.pvalues.values[1:],index=cols)
    pmax=max(p)
    feature_with_p_max=p.idxmax()
    if pmax>0.05:
        cols.remove(feature_with_p_max)
    else:
        break
        
selected_cols=cols
print(selected_cols)
# Out:
# ['% Iron Feed', '% Silica Feed', 'Starch Flow', 'Amina Flow', 'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density', 'Flotation Column 01 Air Flow', 'Flotation Column 02 Air Flow', 'Flotation Column 03 Air Flow', 'Flotation Column 04 Air Flow', 'Flotation Column 05 Air Flow', 'Flotation Column 07 Air Flow', 'Flotation Column 01 Level', 'Flotation Column 02 Level', 'Flotation Column 03 Level', 'Flotation Column 04 Level', 'Flotation Column 05 Level', 'Flotation Column 06 Level', 'Flotation Column 07 Level', '% Iron Concentrate']

# %% [markdown]
# ## 1. Base Model

# %%
import statsmodels.api as sm
xc=sm.add_constant(X[selected_cols])
xc=xc.drop([],axis=1)
model=sm.OLS(y,xc).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     % Silica Concentrate   R-squared:                       0.680
# Model:                              OLS   Adj. R-squared:                  0.680
# Method:                   Least Squares   F-statistic:                 5.208e+04
# Date:                  Fri, 29 May 2020   Prob (F-statistic):               0.00
# Time:                          17:47:54   Log-Likelihood:            -4.9900e+05
# No. Observations:                515397   AIC:                         9.980e+05
# Df Residuals:                    515375   BIC:                         9.983e+05
# Df Model:                            21
# Covariance Type:              nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           46.1960      0.185    250.128      0.000      45.834      46.558
# % Iron Feed                      0.0249      0.001     32.942      0.000       0.023       0.026
# % Silica Feed                    0.0282      0.001     49.555      0.000       0.027       0.029
# Starch Flow                   -1.78e-05   8.17e-07    -21.800      0.000   -1.94e-05   -1.62e-05
# Amina Flow                       0.0007   1.45e-05     46.925      0.000       0.001       0.001
# Ore Pulp Flow                    0.0042      0.000     41.219      0.000       0.004       0.004
# Ore Pulp pH                      0.0462      0.003     18.237      0.000       0.041       0.051
# Ore Pulp Density                 0.1715      0.018      9.393      0.000       0.136       0.207
# Flotation Column 01 Air Flow    -0.0052      0.000    -49.354      0.000      -0.005      -0.005
# Flotation Column 02 Air Flow    -0.0014   6.13e-05    -23.055      0.000      -0.002      -0.001
# Flotation Column 03 Air Flow    -0.0010      0.000     -8.688      0.000      -0.001      -0.001
# Flotation Column 04 Air Flow     0.0024      0.000      5.370      0.000       0.002       0.003
# Flotation Column 05 Air Flow     0.0144      0.000     53.440      0.000       0.014       0.015
# Flotation Column 07 Air Flow     0.0011   4.56e-05     24.919      0.000       0.001       0.001
# Flotation Column 01 Level       -0.0003   1.16e-05    -25.133      0.000      -0.000      -0.000
# Flotation Column 02 Level       -0.0002   1.06e-05    -14.773      0.000      -0.000      -0.000
# Flotation Column 03 Level    -8.603e-05   9.15e-06     -9.406      0.000      -0.000   -6.81e-05
# Flotation Column 04 Level       -0.0001   1.39e-05     -9.762      0.000      -0.000      -0.000
# Flotation Column 05 Level       -0.0002   1.72e-05     -9.780      0.000      -0.000      -0.000
# Flotation Column 06 Level       -0.0002   1.33e-05    -15.673      0.000      -0.000      -0.000
# Flotation Column 07 Level        0.0002   1.63e-05     11.378      0.000       0.000       0.000
# % Iron Concentrate              -0.7873      0.001   -922.085      0.000      -0.789      -0.786
# ==============================================================================
# Omnibus:                     9394.344   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14029.402
# Skew:                           0.204   Prob(JB):                         0.00
# Kurtosis:                       3.698   Cond. No.                     7.16e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.16e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
residuals=model.resid
sns.distplot(residuals)

# %%
import scipy.stats as stats
stats.probplot(residuals,plot=plt)
plt.show()

# %% [markdown]
# ### Autocorrelation Check

# %%
import statsmodels.tsa.api as smt
acf=smt.graphics.plot_acf(residuals,lags=40)
acf.show()
# Out:
# C:\Users\pravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Multicollinearity Check

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
pd.DataFrame({'vif':vif},index=X.columns).T
# Out:
#      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  Ore Pulp Flow  \
# vif  2182.523221     101.879243     8.276451   66.177197    2046.833616
#
#      Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# vif   783.622912       1158.820584                   1102.363187
#
#      Flotation Column 02 Air Flow  Flotation Column 03 Air Flow  ...  \
# vif                    370.992333                   1339.822031  ...
#
#      Flotation Column 06 Air Flow  Flotation Column 07 Air Flow  \
# vif                     404.49158                    428.908241
#
#      Flotation Column 01 Level  Flotation Column 02 Level  \
# vif                  48.887797                  41.524997
#
#      Flotation Column 03 Level  Flotation Column 04 Level  \
# vif                  32.620541                  45.295414
#
#      Flotation Column 05 Level  Flotation Column 06 Level  \
# vif                  71.379307                  42.783424
#
#      Flotation Column 07 Level  % Iron Concentrate
# vif                  62.514508         3688.385273
#
# [1 rows x 22 columns]

# %%
from sklearn import metrics

# %% [markdown]
# ### 2.Linear Regression -ML

# %%
y=train['% Silica Concentrate']
X=train.drop(['% Silica Concentrate'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                        test_size=0.30, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train_pred=lr.predict(X_train)
print ("intercept:",lr.intercept_)
print ("n_coefficients:         ",lr.coef_)
# Out:
# feature_importances: 46.172053051770945
# n_coefficients:          [ 2.53068214e-02  2.86200121e-02 -1.78123397e-05  6.72013752e-04
#   4.18983369e-03  4.56012131e-02  1.85864366e-01 -5.04612177e-03
#  -1.41804497e-03 -1.06638135e-03  2.51320031e-03  1.42165454e-02
#  -6.41673709e-05  1.16511440e-03 -2.86641193e-04 -1.58248364e-04
#  -8.41935912e-05 -1.36528449e-04 -1.46378391e-04 -2.17879968e-04
#   1.76852200e-04 -7.87160533e-01]

# %%
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6800106774894907
# L1 Mean absolute Error:  0.4919007545567008
# L2 Mean square Error:  0.40546089694682397
# L2 RMSE:  0.6367581149438333

# %%
y_test_pred=lr.predict(X_test)

# %%
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.6790406529874597
# L1 Mean absolute Error:  0.4931188760495132
# L2 Mean square Error:  0.40710915840680223
# L2 RMSE:  0.6380510625387299

# %% [markdown]
# ### Model using Backward Elimination Model

# %% [markdown]
# ### 4.Lasso/Ridge/ElasticNet

# %% [markdown]
# ## 4.1 Lasso

# %%
from sklearn.linear_model import Lasso,LassoCV
lasso=Lasso(alpha=0.001,normalize=True)

# %%
lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=True, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_train_pred=lasso.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.35706566053573807
# L1 Mean absolute Error:  0.725660628625641
# L2 Mean square Error:  0.814666976734925
# L2 RMSE:  0.902589040890108

# %%
y_test_pred=lasso.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.35576200337731967
# L1 Mean absolute Error:  0.7268745941757626
# L2 Mean square Error:  0.8171601514645912
# L2 RMSE:  0.9039691097955678

# %%
n_alphas = 50
alphas = np.linspace(0.1,4.5, n_alphas)
coefs=[]
lasso = Lasso()
for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(X, y)
    coefs.append(lasso.coef_)
    
plt.plot(alphas, coefs)
plt.xlabel('alphas')
plt.ylabel('coefs')
plt.show()

# %%
n_alphas=50
alphas=np.linspace(0.1,1, n_alphas)

lasso_cv = LassoCV(alphas=alphas, cv=3, random_state=22)
lasso_cv.fit(X,y)
# Out:
# LassoCV(alphas=array([0.1       , 0.11836735, 0.13673469, 0.15510204, 0.17346939,
#        0.19183673, 0.21020408, 0.22857143, 0.24693878, 0.26530612,
#        0.28367347, 0.30204082, 0.32040816, 0.33877551, 0.35714286,
#        0.3755102 , 0.39387755, 0.4122449 , 0.43061224, 0.44897959,
#        0.46734694, 0.48571429, 0.50408163, 0.52244898, 0.54081633,
#        0.55918367, 0.57755102, 0.59591837, 0.61428571, 0.63265306,
#        0.65102...
#        0.74285714, 0.76122449, 0.77959184, 0.79795918, 0.81632653,
#        0.83469388, 0.85306122, 0.87142857, 0.88979592, 0.90816327,
#        0.92653061, 0.94489796, 0.96326531, 0.98163265, 1.        ]),
#         copy_X=True, cv=3, eps=0.001, fit_intercept=True, max_iter=1000,
#         n_alphas=100, n_jobs=None, normalize=False, positive=False,
#         precompute='auto', random_state=22, selection='cyclic', tol=0.0001,
#         verbose=False)

# %%
lasso_cv.alpha_
# Out:
# 0.1

# %%
lasso = Lasso(alpha=lasso_cv.alpha_)
lasso.fit(X_train, y_train)
lasso.coef_
pd.DataFrame(lasso.coef_, X.columns, columns=['coefs'])
# Out:
#                                  coefs
# % Iron Feed                  -0.000000
# % Silica Feed                 0.007074
# Starch Flow                  -0.000019
# Amina Flow                    0.000930
# Ore Pulp Flow                 0.002473
# Ore Pulp pH                   0.000000
# Ore Pulp Density             -0.000000
# Flotation Column 01 Air Flow -0.004835
# Flotation Column 02 Air Flow -0.000878
# Flotation Column 03 Air Flow -0.001811
# Flotation Column 04 Air Flow  0.000000
# Flotation Column 05 Air Flow  0.001722
# Flotation Column 06 Air Flow  0.000000
# Flotation Column 07 Air Flow  0.000865
# Flotation Column 01 Level    -0.000227
# Flotation Column 02 Level    -0.000128
# Flotation Column 03 Level    -0.000040
# Flotation Column 04 Level    -0.000188
# Flotation Column 05 Level    -0.000272
# Flotation Column 06 Level    -0.000206
# Flotation Column 07 Level     0.000042
# % Iron Concentrate           -0.692140

# %%
y_train_pred=lasso.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.670492163765895
# L1 Mean absolute Error:  0.49921338238360524
# L2 Mean square Error:  0.41752187786234507
# L2 RMSE:  0.6461593285423844

# %%
y_test_pred=lasso.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.6694330429804884
# L1 Mean absolute Error:  0.5004291662609394
# L2 Mean square Error:  0.41929558033420616
# L2 RMSE:  0.6475303702022062

# %% [markdown]
# ### 4.2 Ridge

# %%
from sklearn.linear_model import Ridge,RidgeCV
ridge=Ridge(alpha=0.05)

# %%
ridge.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.05, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
y_train_pred=ridge.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6800106774892487
# L1 Mean absolute Error:  0.4919007656139003
# L2 Mean square Error:  0.4054608969471308
# L2 RMSE:  0.6367581149440742

# %%
y_test_pred=ridge.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.6790406550825232
# L1 Mean absolute Error:  0.4931188839868137
# L2 Mean square Error:  0.4071091557493955
# L2 RMSE:  0.6380510604562895

# %%
ridge.fit(X, y)
ridge.coef_
pd.DataFrame(ridge.coef_, X.columns, columns=['coefs'])
# Out:
#                                  coefs
# % Iron Feed                   0.024929
# % Silica Feed                 0.028240
# Starch Flow                  -0.000018
# Amina Flow                    0.000682
# Ore Pulp Flow                 0.004197
# Ore Pulp pH                   0.045883
# Ore Pulp Density              0.169710
# Flotation Column 01 Air Flow -0.005147
# Flotation Column 02 Air Flow -0.001416
# Flotation Column 03 Air Flow -0.000988
# Flotation Column 04 Air Flow  0.002367
# Flotation Column 05 Air Flow  0.014383
# Flotation Column 06 Air Flow -0.000086
# Flotation Column 07 Air Flow  0.001199
# Flotation Column 01 Level    -0.000290
# Flotation Column 02 Level    -0.000155
# Flotation Column 03 Level    -0.000087
# Flotation Column 04 Level    -0.000136
# Flotation Column 05 Level    -0.000171
# Flotation Column 06 Level    -0.000209
# Flotation Column 07 Level     0.000186
# % Iron Concentrate           -0.787316

# %%
n_alphas = 200
alphas = np.logspace(-3, 2, n_alphas)
coefs=[]
model = Ridge()
for a in alphas:
    model.set_params(alpha=a)
    model.fit(X, y)
    coefs.append(model.coef_)
    
plt.plot(alphas, coefs)
plt.xlabel('alphas')
plt.ylabel('coefs')
plt.show()

# %%
n_alphas = 1000
alphas = np.logspace(-2, 0)

ridge_cv = RidgeCV(alphas=alphas, store_cv_values=True)
ridge_cv.fit(X, y)

ridge_cv.alpha_
# Out:
# 1.0

# %%
ridge=Ridge(alpha=ridge_cv.alpha_)
ridge.fit(X_train,y_train)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
y_train_pred=ridge.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6800106773928891
# L1 Mean absolute Error:  0.49190097552076184
# L2 Mean square Error:  0.4054608970692287
# L2 RMSE:  0.6367581150399488

# %%
y_test_pred=ridge.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.6790406947471004
# L1 Mean absolute Error:  0.4931190346239968
# L2 Mean square Error:  0.40710910543831164
# L2 RMSE:  0.6380510210306944

# %% [markdown]
# ### 4.3 Elastic Net/Elastic Net CV

# %%
from sklearn.linear_model import ElasticNet, ElasticNetCV
enet = ElasticNet(alpha=0.1)
enet.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_train_pred=enet.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.673487758751757
# L1 Mean absolute Error:  0.49736907756441157
# L2 Mean square Error:  0.41372613674096087
# L2 RMSE:  0.6432154668079436

# %%
y_test_pred=enet.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.6724865442336405
# L1 Mean absolute Error:  0.4985507685850429
# L2 Mean square Error:  0.41542247822038514
# L2 RMSE:  0.6445327596176824

# %%
pd.DataFrame(enet.coef_, X.columns, columns=['coefs'])
# Out:
#                                  coefs
# % Iron Feed                  -0.000000
# % Silica Feed                 0.008694
# Starch Flow                  -0.000018
# Amina Flow                    0.000891
# Ore Pulp Flow                 0.003130
# Ore Pulp pH                   0.000000
# Ore Pulp Density             -0.000000
# Flotation Column 01 Air Flow -0.004921
# Flotation Column 02 Air Flow -0.001153
# Flotation Column 03 Air Flow -0.001600
# Flotation Column 04 Air Flow  0.000000
# Flotation Column 05 Air Flow  0.006631
# Flotation Column 06 Air Flow  0.000000
# Flotation Column 07 Air Flow  0.001154
# Flotation Column 01 Level    -0.000249
# Flotation Column 02 Level    -0.000147
# Flotation Column 03 Level    -0.000044
# Flotation Column 04 Level    -0.000173
# Flotation Column 05 Level    -0.000265
# Flotation Column 06 Level    -0.000211
# Flotation Column 07 Level     0.000085
# % Iron Concentrate           -0.706415

# %%
n_alphas = 100
alphas = np.logspace(-3, -1, n_alphas)
coefs=[]
enet = ElasticNet()
for a in alphas:
    enet.set_params(alpha=a)
    enet.fit(X, y)
    coefs.append(model.coef_)
    
plt.plot(alphas, coefs)
plt.xlabel('alphas')
plt.ylabel('coefs')
plt.show()

# %%
n_alphas = 100
alphas = np.logspace(-3, 1, n_alphas)

en_cv = ElasticNetCV(alphas=alphas, cv=3)
en_cv.fit(X, y)
en_cv.alpha_
# Out:
# 0.001

# %%
enet = ElasticNet(alpha=en_cv.alpha_)
enet.fit(X_train,y_train)
# Out:
# ElasticNet(alpha=0.001, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_train_pred=enet.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6799434069437265
# L1 Mean absolute Error:  0.49216396643775984
# L2 Mean square Error:  0.40554613596545647
# L2 RMSE:  0.6368250434502842

# %%
y_train_pred=enet.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6799434069437265
# L1 Mean absolute Error:  0.49216396643775984
# L2 Mean square Error:  0.40554613596545647
# L2 RMSE:  0.6368250434502842

# %% [markdown]
# ## 3. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### Changing max depth

# %%
train_accuracy=[]
test_accuracy=[]

for depth in range(5,20):
    dt_model=DecisionTreeRegressor(max_depth=depth,random_state=42)
    dt_model.fit(X_train,y_train)
    train_accuracy.append(dt_model.score(X_train,y_train))
    test_accuracy.append(dt_model.score(X_test,y_test))

# %%
frame=pd.DataFrame({'max_depth':range(5,20),'train_accuracy':train_accuracy,'test_accuracy':test_accuracy})
print(frame)
# Out:
#     max_depth  train_accuracy  test_accuracy
# 0           5        0.726269       0.722585
# 1           6        0.752208       0.748472
# 2           7        0.777847       0.773844
# 3           8        0.804083       0.799744
# 4           9        0.832177       0.827583
# 5          10        0.861577       0.856893
# 6          11        0.888367       0.882672
# 7          12        0.913663       0.907215
# 8          13        0.935841       0.929030
# 9          14        0.953936       0.946190
# 10         15        0.967497       0.959209
# 11         16        0.976875       0.968504
# 12         17        0.984070       0.975361
# 13         18        0.989252       0.980021
# 14         19        0.993101       0.983622

# %%
plt.figure(figsize=(13,6))
plt.plot(frame['max_depth'],frame['train_accuracy'],marker='o')
plt.plot(frame['max_depth'],frame['test_accuracy'],marker='o')
plt.xlabel('Depth of Tree')
plt.ylabel('Accuracy Performance')
plt.show()

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
print ("feature_importances:",dtr.feature_importances_)
print ("Best params: \n        ",dtr.get_params)
print('n feature',dtr.n_features_)
print(dtr.n_outputs_)
# Out:
# feature_importances: [0.04030863 0.0413876  0.01022302 0.01752982 0.00742071 0.02619319
#  0.01589585 0.01833159 0.00405793 0.0032808  0.01175437 0.01337408
#  0.00602873 0.00161719 0.01091148 0.00608055 0.02008062 0.00237463
#  0.00580144 0.00433775 0.00379399 0.72921605]
# Best params:
#          <bound method BaseEstimator.get_params of DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')>
# n feature 22
# 1

# %%
y_train_pred=dtr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.9999999986412665
# L1 Mean absolute Error:  5.2647899291722545e-06
# L2 Mean square Error:  1.721661405212188e-09
# L2 RMSE:  4.1492907890532185e-05

# %%
y_test_pred=dtr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.9893805928293701
# L1 Mean absolute Error:  0.012371177161746969
# L2 Mean square Error:  0.013469799076595793
# L2 RMSE:  0.11605946353742892

# %% [markdown]
# ## 4. Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
print ("feature_importances:",rfr.feature_importances_)
print ("n_coefficients:         ",rfr.get_params)
print('n feature',rfr.n_features_)
print(rfr.n_outputs_)
# Out:
# feature_importances: [0.03730154 0.04093893 0.00936405 0.01794512 0.0062913  0.02631464
#  0.01470905 0.01977322 0.0045772  0.00337254 0.01227437 0.01272088
#  0.00576613 0.00173899 0.01124861 0.00672207 0.02155703 0.00262675
#  0.00619703 0.0045472  0.00353284 0.73048052]
# n_coefficients:          <bound method BaseEstimator.get_params of RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)>
# n feature 22
# 1

# %%
y_train_pred=rfr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print(' Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.9996376506801848
# L1 Mean absolute Error:  0.005879372944881321
# L2 Mean square Error:  0.00045913557073613376
# L2 RMSE:  0.021427449002065873

# %%
y_test_pred=rfr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.9973536722122649
# L1 Mean absolute Error:  0.015828176002846608
# L2 Mean square Error:  0.0033566378065047007
# L2 RMSE:  0.05793649805178684

# %% [markdown]
# ## Considering Random Forest Regressor Base Model as the final model. Implementing the model in the test data set

# %%
test
# Out:
#         % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  Ore Pulp Flow  \
# 609291        48.81          25.31      3141.51     406.611     378.378000
# 284465        64.03           6.26      3253.02     428.276     399.526000
# 249890        64.03           6.26      3880.75     408.478     403.711000
# 72525         55.90          14.26      2248.05     454.821     400.826000
# 380496        44.90          30.12      3738.10     513.570     405.783000
# ...             ...            ...          ...         ...            ...
# 77916         57.37          13.06      1967.99     447.240     378.260403
# 62759         57.34          13.06      2631.65     570.983     399.303000
# 165528        55.94          13.85      2145.78     499.480     396.957000
# 573303        57.46          10.80      4565.84     421.939     376.694429
# 424351        59.62          10.43      2271.96     580.263     400.427000
#
#         Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 609291      9.74367           1.66080                       299.649
# 284465      9.78977           1.64372                       299.904
# 249890      9.60092           1.65626                       302.618
# 72525       9.81336           1.76796                       250.049
# 380496     10.62650           1.73132                       300.271
# ...             ...               ...                           ...
# 77916       9.60670           1.77355                       250.524
# 62759       9.64725           1.77466                       249.849
# 165528      9.58862           1.70391                       299.927
# 573303      9.71766           1.62060                       301.199
# 424351      9.62528           1.73614                       297.109
#
#         Flotation Column 02 Air Flow  Flotation Column 03 Air Flow  ...  \
# 609291                       298.273                       299.579  ...
# 284465                       302.226                       298.431  ...
# 249890                       299.817                       299.762  ...
# 72525                        245.660                       249.619  ...
# 380496                       301.134                       302.389  ...
# ...                              ...                           ...  ...
# 77916                        252.277                       249.188  ...
# 62759                        248.870                       248.531  ...
# 165528                       302.258                       298.668  ...
# 573303                       297.953                       300.775  ...
# 424351                       299.891                       297.949  ...
#
#         Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# 609291                       342.728                    495.569
# 284465                       298.828                    543.276
# 249890                       298.663                    457.195
# 72525                        251.616                    592.466
# 380496                       297.631                    430.747
# ...                              ...                        ...
# 77916                        249.270                    603.235
# 62759                        248.670                    805.740
# 165528                       300.005                    462.142
# 573303                       349.109                    398.723
# 424351                       300.398                    412.034
#
#         Flotation Column 02 Level  Flotation Column 03 Level  \
# 609291                    500.169                    490.141
# 284465                    544.950                    553.104
# 249890                    432.451                    449.851
# 72525                     598.074                    594.385
# 380496                    392.123                    401.438
# ...                           ...                        ...
# 77916                     300.864                    626.991
# 62759                     801.470                    806.507
# 165528                    456.572                    463.437
# 573303                    381.818                    387.608
# 424351                    406.112                    435.862
#
#         Flotation Column 04 Level  Flotation Column 05 Level  \
# 609291                    376.312                    362.991
# 284465                    471.211                    454.978
# 249890                    308.594                    334.186
# 72525                     432.877                    447.003
# 380496                    450.215                    447.724
# ...                           ...                        ...
# 77916                     369.025                    435.501
# 62759                     410.284                    395.062
# 165528                    255.109                    365.464
# 573303                    296.541                    271.165
# 424351                    386.761                    406.113
#
#         Flotation Column 06 Level  Flotation Column 07 Level  \
# 609291                    394.750                 314.727000
# 284465                    383.711                 395.462000
# 249890                    494.111                 324.158000
# 72525                     446.086                 452.944000
# 380496                    434.588                 463.290000
# ...                           ...                        ...
# 77916                     382.913                 434.072000
# 62759                     451.584                 411.155000
# 165528                    343.433                 346.139000
# 573303                    286.667                 260.684966
# 424351                    412.542                 439.181000
#
#         % Iron Concentrate  % Silica Concentrate
# 609291               65.52                  1.22
# 284465               66.08                  2.11
# 249890               64.98                  1.43
# 72525                65.16                  2.28
# 380496               64.60                  2.62
# ...                    ...                   ...
# 77916                66.61                  1.44
# 62759                65.88                  2.03
# 165528               63.70                  4.03
# 573303               65.44                  2.08
# 424351               66.44                  1.61
#
# [220885 rows x 23 columns]

# %%
expected_output=train['% Silica Concentrate']
expected_input=train.drop(['% Silica Concentrate'],axis=1)

# %%
y_pred=rfr.predict(expected_input)

# %%
print('R2 of Output: ', metrics.r2_score(expected_output,y_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(expected_output,y_pred))
print('Mean square Error: ',metrics.mean_squared_error(expected_output,y_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(expected_output,y_pred)))
# Out:
# R2 of Output:  0.9989519608598195
# L1 Mean absolute Error:  0.00886403123513639
# L2 Mean square Error:  0.0013283913011624571
# L2 RMSE:  0.03644710278146203

# %% [markdown]
# ## Gradient Boosting

# %%
params = {
    'n_estimators': 80,
    'max_depth': 12,
    'learning_rate': 0.1,
    'criterion': 'mse'
    }

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(**params)

# %%
gbr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=12,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=80,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_train_pred=gbr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.9954026056159501
# L1 Mean absolute Error:  0.050673165876619464
# L2 Mean square Error:  0.005825393284846115
# L2 RMSE:  0.07632426406357362

# %%
y_test_pred=gbr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.9928342370782505
# L1 Mean absolute Error:  0.058876907981426266
# L2 Mean square Error:  0.00908915019789758
# L2 RMSE:  0.09533703476560187
