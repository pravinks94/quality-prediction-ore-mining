# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('DATA/MiningProcess_Flotation_Plant_Database.csv',decimal=',').drop_duplicates()
df.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1  2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2  2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3  2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4  2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
#    Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# 0                       253.235  ...                       250.884
# 1                       250.532  ...                       248.994
# 2                       247.874  ...                       248.071
# 3                       254.487  ...                       251.147
# 4                       252.136  ...                       248.928
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    457.396                    432.962
# 1                    451.891                    429.560
# 2                    451.240                    468.927
# 3                    452.441                    458.165
# 4                    452.441                    452.900
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    424.954                    443.558
# 1                    432.939                    448.086
# 2                    434.610                    449.688
# 3                    442.865                    446.210
# 4                    450.523                    453.670
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                    502.255                    446.370
# 1                    496.363                    445.922
# 2                    484.411                    447.826
# 3                    471.411                    437.690
# 4                    462.598                    443.682
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                    523.344               66.91                  1.31
# 1                    498.075               66.91                  1.31
# 2                    458.567               66.91                  1.31
# 3                    427.669               66.91                  1.31
# 4                    425.679               66.91                  1.31
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (736282, 24)

# %%
df.columns
# Out:
# Index(['date', '% Iron Feed', '% Silica Feed', 'Starch Flow', 'Amina Flow',
#        'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density',
#        'Flotation Column 01 Air Flow', 'Flotation Column 02 Air Flow',
#        'Flotation Column 03 Air Flow', 'Flotation Column 04 Air Flow',
#        'Flotation Column 05 Air Flow', 'Flotation Column 06 Air Flow',
#        'Flotation Column 07 Air Flow', 'Flotation Column 01 Level',
#        'Flotation Column 02 Level', 'Flotation Column 03 Level',
#        'Flotation Column 04 Level', 'Flotation Column 05 Level',
#        'Flotation Column 06 Level', 'Flotation Column 07 Level',
#        '% Iron Concentrate', '% Silica Concentrate'],
#       dtype='object')

# %% [markdown]
# # Date in Mining Ores

# %%
df.groupby(['date'])

# %%
plt.figure(figsize=(30,10))
df.groupby(['date']).mean()['% Silica Concentrate'].plot()
plt.show()

# %%
plt.figure(figsize=(30,10))
df.groupby(['date']).mean()['% Iron Concentrate'].plot()
plt.show()

# %%
df.groupby(['% Silica Concentrate']).mean()
# Out:
#                       % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# % Silica Concentrate
# 0.600000                    48.81          25.31  3507.572389  430.847311
# 0.660000                    48.81          25.31  2185.361279  419.244482
# 0.740000                    48.81          25.31  3890.823333  458.506367
# 0.750000                    48.81          25.31  2975.124778  393.377690
# 0.770000                    56.45          13.57  2169.709250  505.566494
# ...                           ...            ...          ...         ...
# 5.529187                    57.46          10.80  4851.520000  656.820000
# 5.529390                    57.46          10.80  4836.140000  624.736000
# 5.529593                    57.46          10.80  4824.430000  642.565000
# 5.529797                    57.46          10.80  4801.680000  637.808000
# 5.530000                    49.80          22.34  3414.716557  584.756947
#
#                       Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# % Silica Concentrate
# 0.600000                 379.343667    10.291061          1.700894
# 0.660000                 381.502420     9.469579          1.684721
# 0.740000                 381.110714    10.395589          1.687037
# 0.750000                 381.802851    10.032917          1.691862
# 0.770000                 399.946089     9.599748          1.740165
# ...                             ...          ...               ...
# 5.529187                 401.131000    10.341000          1.714080
# 5.529390                 401.029000    10.340400          1.713990
# 5.529593                 403.687000    10.339800          1.713900
# 5.529797                 405.080000    10.339700          1.713810
# 5.530000                 400.118455     9.819079          1.707561
#
#                       Flotation Column 01 Air Flow  \
# % Silica Concentrate
# 0.600000                                299.788706
# 0.660000                                299.946906
# 0.740000                                299.857589
# 0.750000                                299.739750
# 0.770000                                250.016756
# ...                                            ...
# 5.529187                                300.249000
# 5.529390                                299.869000
# 5.529593                                299.937000
# 5.529797                                300.528000
# 5.530000                                299.795376
#
#                       Flotation Column 02 Air Flow  \
# % Silica Concentrate
# 0.600000                                249.868783
# 0.660000                                300.510120
# 0.740000                                249.901839
# 0.750000                                250.036283
# 0.770000                                249.942567
# ...                                            ...
# 5.529187                                292.510000
# 5.529390                                298.185000
# 5.529593                                298.919000
# 5.529797                                292.035000
# 5.530000                                299.886991
#
#                       Flotation Column 03 Air Flow  ...  \
# % Silica Concentrate                                ...
# 0.600000                                299.859722  ...
# 0.660000                                299.952711  ...
# 0.740000                                299.920178  ...
# 0.750000                                299.923211  ...
# 0.770000                                250.024272  ...
# ...                                            ...  ...
# 5.529187                                297.188000  ...
# 5.529390                                298.148000  ...
# 5.529593                                300.501000  ...
# 5.529797                                302.124000  ...
# 5.530000                                299.883157  ...
#
#                       Flotation Column 06 Air Flow  \
# % Silica Concentrate
# 0.600000                                299.580378
# 0.660000                                249.966511
# 0.740000                                299.991356
# 0.750000                                299.779978
# 0.770000                                250.022533
# ...                                            ...
# 5.529187                                291.279000
# 5.529390                                298.651000
# 5.529593                                308.092000
# 5.529797                                299.051000
# 5.530000                                299.776535
#
#                       Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# % Silica Concentrate
# 0.600000                                287.760011                 549.482956
# 0.660000                                250.045646                 553.295064
# 0.740000                                299.922417                 550.379206
# 0.750000                                250.008144                 556.294867
# 0.770000                                250.085961                 603.269472
# ...                                            ...                        ...
# 5.529187                                302.016000                 400.282000
# 5.529390                                299.579000                 373.471000
# 5.529593                                298.666000                 376.051000
# 5.529797                                299.060000                 444.451000
# 5.530000                                299.626998                 466.203320
#
#                       Flotation Column 02 Level  Flotation Column 03 Level  \
# % Silica Concentrate
# 0.600000                             548.923283                 549.972750
# 0.660000                             504.124909                 750.439797
# 0.740000                             549.588667                 549.821300
# 0.750000                             553.436206                 560.644808
# 0.770000                             600.161144                 601.072817
# ...                                         ...                        ...
# 5.529187                             440.689000                 390.901000
# 5.529390                             396.158000                 396.315000
# 5.529593                             383.141000                 394.713000
# 5.529797                             252.555000                 392.063000
# 5.530000                             470.200318                 543.103345
#
#                       Flotation Column 04 Level  Flotation Column 05 Level  \
# % Silica Concentrate
# 0.600000                             516.092072                 517.980733
# 0.660000                             454.544115                 453.474052
# 0.740000                             498.237644                 499.867883
# 0.750000                             562.173389                 550.175139
# 0.770000                             449.567033                 449.980850
# ...                                         ...                        ...
# 5.529187                             314.406000                 339.873000
# 5.529390                             356.765000                 352.086000
# 5.529593                             394.682000                 370.609000
# 5.529797                             334.993000                 340.588000
# 5.530000                             397.303592                 400.015793
#
#                       Flotation Column 06 Level  Flotation Column 07 Level  \
# % Silica Concentrate
# 0.600000                             511.288872                 513.563067
# 0.660000                             500.682550                 502.348081
# 0.740000                             499.730194                 498.209325
# 0.750000                             552.597044                 551.615594
# 0.770000                             447.103056                 450.250956
# ...                                         ...                        ...
# 5.529187                             353.915000                 371.580000
# 5.529390                             399.213000                 359.175000
# 5.529593                             452.038000                 368.375000
# 5.529797                             427.846000                 343.693000
# 5.530000                             401.980517                 399.966089
#
#                       % Iron Concentrate
# % Silica Concentrate
# 0.600000                       66.570000
# 0.660000                       65.120000
# 0.740000                       65.610000
# 0.750000                       66.780000
# 0.770000                       66.900000
# ...                                  ...
# 5.529187                       62.360000
# 5.529390                       62.360000
# 5.529593                       62.360000
# 5.529797                       62.360000
# 5.530000                       63.658947
#
# [55569 rows x 22 columns]

# %%
df.groupby(['% Iron Concentrate']).mean()
# Out:
#                     % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# % Iron Concentrate
# 62.050000                 57.08          13.35  2234.233667  542.608150
# 62.052219                 59.78           9.29  2179.080000  559.878000
# 62.053684                 54.38          17.41  2152.340000  576.782000
# 62.054438                 59.78           9.29  2176.350000  563.970000
# 62.055014                 59.78           9.29  2404.300000  580.116000
# ...                         ...            ...          ...         ...
# 67.630000                 64.03           6.26  4052.176444  450.924417
# 67.660000                 49.35          24.90  3077.049500  377.148094
# 67.670000                 48.81          25.31  3641.604167  404.219844
# 67.990000                 55.78          12.85  2588.626106  431.233456
# 68.010000                 47.79          27.08  4322.071578  517.330928
#
#                     Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# % Iron Concentrate
# 62.050000              400.167157     9.764361          1.766480
# 62.052219              396.816000     9.788190          1.771370
# 62.053684              404.297000     9.750870          1.783270
# 62.054438              397.320000     9.789000          1.770600
# 62.055014              399.114000     9.998960          1.783490
# ...                           ...          ...               ...
# 67.630000              400.162194    10.158235          1.594675
# 67.660000              400.064061    10.244143          1.658189
# 67.670000              380.739842     9.933260          1.704377
# 67.990000              400.952456    10.693607          1.543400
# 68.010000              399.700861    10.463737          1.732864
#
#                     Flotation Column 01 Air Flow  \
# % Iron Concentrate
# 62.050000                             275.036800
# 62.052219                             300.484000
# 62.053684                             250.269000
# 62.054438                             300.526000
# 62.055014                             299.487000
# ...                                          ...
# 67.630000                             299.930939
# 67.660000                             249.998239
# 67.670000                             299.911356
# 67.990000                             299.981528
# 68.010000                             299.859072
#
#                     Flotation Column 02 Air Flow  \
# % Iron Concentrate
# 62.050000                             275.150456
# 62.052219                             303.163000
# 62.053684                             257.080000
# 62.054438                             302.561000
# 62.055014                             306.062000
# ...                                          ...
# 67.630000                             299.651872
# 67.660000                             249.948056
# 67.670000                             298.836394
# 67.990000                             300.051550
# 68.010000                             299.737372
#
#                     Flotation Column 03 Air Flow  ...  \
# % Iron Concentrate                                ...
# 62.050000                             274.954469  ...
# 62.052219                             302.548000  ...
# 62.053684                             251.587000  ...
# 62.054438                             301.143000  ...
# 62.055014                             301.820000  ...
# ...                                          ...  ...
# 67.630000                             299.908261  ...
# 67.660000                             250.111900  ...
# 67.670000                             299.982222  ...
# 67.990000                             299.870878  ...
# 68.010000                             299.957161  ...
#
#                     Flotation Column 06 Air Flow  \
# % Iron Concentrate
# 62.050000                             274.577364
# 62.052219                             297.373000
# 62.053684                             253.345000
# 62.054438                             298.174000
# 62.055014                             295.499000
# ...                                          ...
# 67.630000                             299.995489
# 67.660000                             299.998294
# 67.670000                             349.317211
# 67.990000                             299.905022
# 68.010000                             300.061800
#
#                     Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# % Iron Concentrate
# 62.050000                             275.109861                 569.033331
# 62.052219                             299.907000                 452.648000
# 62.053684                             251.807000                 605.591000
# 62.054438                             298.926000                 450.166000
# 62.055014                             296.715000                 465.839000
# ...                                          ...                        ...
# 67.630000                             299.936183                 500.537472
# 67.660000                             300.866928                 600.451433
# 67.670000                             349.772067                 500.660422
# 67.990000                             299.571333                 400.753367
# 68.010000                             299.814578                 500.424794
#
#                     Flotation Column 02 Level  Flotation Column 03 Level  \
# % Iron Concentrate
# 62.050000                          647.687120                 877.901875
# 62.052219                          464.109000                 870.505128
# 62.053684                          753.845963                 884.255629
# 62.054438                          459.298000                 870.491544
# 62.055014                          466.631000                 872.963834
# ...                                       ...                        ...
# 67.630000                          488.634144                 517.281154
# 67.660000                          599.180372                 600.377139
# 67.670000                          498.751794                 499.952850
# 67.990000                          397.946039                 399.183533
# 68.010000                          499.444217                 499.406578
#
#                     Flotation Column 04 Level  Flotation Column 05 Level  \
# % Iron Concentrate
# 62.050000                          374.896306                 372.729694
# 62.052219                          271.643000                 334.710000
# 62.053684                          430.078000                 380.590000
# 62.054438                          239.322000                 332.128000
# 62.055014                          386.357000                 354.618000
# ...                                       ...                        ...
# 67.630000                          497.519506                 497.175128
# 67.660000                          500.624361                 499.948867
# 67.670000                          353.228433                 350.180106
# 67.990000                          411.818111                 401.818483
# 68.010000                          499.020506                 499.049967
#
#                     Flotation Column 06 Level  Flotation Column 07 Level  \
# % Iron Concentrate
# 62.050000                          392.507081                 371.004833
# 62.052219                          268.534000                 289.385000
# 62.053684                          512.454000                 359.746000
# 62.054438                          327.958000                 322.669000
# 62.055014                          343.276000                 343.150000
# ...                                       ...                        ...
# 67.630000                          503.977833                 499.653206
# 67.660000                          449.454133                 448.839872
# 67.670000                          354.699483                 353.110700
# 67.990000                          398.992378                 405.573106
# 68.010000                          501.710136                 497.050772
#
#                     % Silica Concentrate
# % Iron Concentrate
# 62.050000                       4.100062
# 62.052219                       3.892902
# 62.053684                       4.532482
# 62.054438                       3.892982
# 62.055014                       3.878549
# ...                                  ...
# 67.630000                       1.050000
# 67.660000                       1.410000
# 67.670000                       1.030000
# 67.990000                       1.100000
# 68.010000                       1.380000
#
# [38696 rows x 22 columns]

# %% [markdown]
# Since dataset is very huge .Considering to split the data into train and test

# %%
# deleting date column

# %%
df=df.drop(['date'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
train,test=train_test_split(df,test_size=0.3)

# %%
print('Train size',train.shape)
print('Test size',test.shape)
# Out:
# Train size (515397, 23)
# Test size (220885, 23)

# %%
import missingno
missingno.matrix(train,figsize=(20,5))

# %%
import missingno
missingno.matrix(test,figsize=(20,5))

# %%
plt.figure(figsize=(30,30))
sns.heatmap(train.corr(),annot=True,linewidths=0.3)
plt.show()

# %%
train.columns[-1]
# Out:
# '% Silica Concentrate'

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515397 entries, 108742 to 466410
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   % Iron Feed                   515397 non-null  float64
#  1   % Silica Feed                 515397 non-null  float64
#  2   Starch Flow                   515397 non-null  float64
#  3   Amina Flow                    515397 non-null  float64
#  4   Ore Pulp Flow                 515397 non-null  float64
#  5   Ore Pulp pH                   515397 non-null  float64
#  6   Ore Pulp Density              515397 non-null  float64
#  7   Flotation Column 01 Air Flow  515397 non-null  float64
#  8   Flotation Column 02 Air Flow  515397 non-null  float64
#  9   Flotation Column 03 Air Flow  515397 non-null  float64
#  10  Flotation Column 04 Air Flow  515397 non-null  float64
#  11  Flotation Column 05 Air Flow  515397 non-null  float64
#  12  Flotation Column 06 Air Flow  515397 non-null  float64
#  13  Flotation Column 07 Air Flow  515397 non-null  float64
#  14  Flotation Column 01 Level     515397 non-null  float64
#  15  Flotation Column 02 Level     515397 non-null  float64
#  16  Flotation Column 03 Level     515397 non-null  float64
#  17  Flotation Column 04 Level     515397 non-null  float64
#  18  Flotation Column 05 Level     515397 non-null  float64
#  19  Flotation Column 06 Level     515397 non-null  float64
#  20  Flotation Column 07 Level     515397 non-null  float64
#  21  % Iron Concentrate            515397 non-null  float64
#  22  % Silica Concentrate          515397 non-null  float64
# dtypes: float64(23)
# memory usage: 94.4 MB

# %%
train.describe()
# Out:
#          % Iron Feed  % Silica Feed    Starch Flow     Amina Flow  \
# count  515397.000000  515397.000000  515397.000000  515397.000000
# mean       56.295174      14.654352    2870.815363     488.204197
# std         5.161163       6.813196    1216.152034      91.258304
# min        42.740000       1.310000       0.006614     241.669000
# 25%        52.670000       8.940000    2075.859048     431.836000
# 50%        56.080000      13.850000    3021.840000     504.414000
# 75%        59.720000      19.600000    3730.540000     553.369000
# max        65.780000      33.400000    6297.100000     739.538000
#
#        Ore Pulp Flow    Ore Pulp pH  Ore Pulp Density  \
# count  515397.000000  515397.000000     515397.000000
# mean      397.570416       9.767957          1.680461
# std         9.705344       0.387236          0.069136
# min       376.249000       8.753340          1.519820
# 25%       394.241000       9.527530          1.647450
# 50%       399.244000       9.798500          1.697600
# 75%       402.965000      10.038800          1.728340
# max       418.641000      10.808100          1.853218
#
#        Flotation Column 01 Air Flow  Flotation Column 02 Air Flow  \
# count                 515397.000000                 515397.000000
# mean                     280.120449                    277.130333
# std                       29.602766                     30.135472
# min                      175.666333                    175.263000
# 25%                      250.276000                    250.453000
# 50%                      299.340000                    296.205000
# 75%                      300.148000                    300.688000
# max                      372.684000                    375.776000
#
#        Flotation Column 03 Air Flow  ...  Flotation Column 07 Air Flow  \
# count                 515397.000000  ...                 515397.000000
# mean                     281.057521  ...                    290.771561
# std                       28.541741  ...                     28.679057
# min                      176.469000  ...                    185.981000
# 25%                      250.846000  ...                    256.259000
# 50%                      298.690000  ...                    299.009000
# 75%                      300.386000  ...                    301.916000
# max                      364.346000  ...                    371.593000
#
#        Flotation Column 01 Level  Flotation Column 02 Level  \
# count              515397.000000              515397.000000
# mean                  520.091196                 522.447044
# std                   131.153615                 128.182954
# min                   149.293000                 210.752000
# 25%                   416.842000                 441.820000
# 50%                   491.651000                 495.792000
# 75%                   594.080000                 595.241000
# max                   862.274000                 828.919000
#
#        Flotation Column 03 Level  Flotation Column 04 Level  \
# count              515397.000000              515397.000000
# mean                  531.183350                 420.030958
# std                   150.859444                  91.770847
# min                   126.255000                 162.201000
# 25%                   411.156000                 356.499000
# 50%                   494.137000                 411.540000
# 75%                   601.294000                 485.204000
# max                   886.822000                 680.359000
#
#        Flotation Column 05 Level  Flotation Column 06 Level  \
# count              515397.000000              515397.000000
# mean                  425.030680                 429.766150
# std                    84.490056                  89.876442
# min                   166.991000                 155.841000
# 25%                   357.566000                 358.355000
# 50%                   408.499000                 424.210000
# 75%                   484.007000                 492.752000
# max                   675.644000                 698.861000
#
#        Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# count              515397.000000       515397.000000         515397.000000
# mean                  420.787660           65.048814              2.327977
# std                    84.853928            1.119105              1.125864
# min                   175.377000           62.050000              0.600000
# 25%                   356.596000           64.368249              1.440000
# 50%                   410.777000           65.210000              2.000000
# 75%                   475.977000           65.860000              3.010000
# max                   659.900000           68.010000              5.530000
#
# [8 rows x 23 columns]

# %% [markdown]
# ## % for Silicon Concentration

# %%
# Deleting date columns and % Iron Concentration
y=train['% Silica Concentrate']
X=train.drop(['% Silica Concentrate'],axis=1)

# %% [markdown]
# ## 1. Base Model

# %%
import statsmodels.api as sm
xc=sm.add_constant(X)
xc=xc.drop([],axis=1)
model=sm.OLS(y,xc).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     % Silica Concentrate   R-squared:                       0.680
# Model:                              OLS   Adj. R-squared:                  0.680
# Method:                   Least Squares   F-statistic:                 4.980e+04
# Date:                  Fri, 29 May 2020   Prob (F-statistic):               0.00
# Time:                          12:48:17   Log-Likelihood:            -4.9872e+05
# No. Observations:                515397   AIC:                         9.975e+05
# Df Residuals:                    515374   BIC:                         9.977e+05
# Df Model:                            22
# Covariance Type:              nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           46.1917      0.186    248.416      0.000      45.827      46.556
# % Iron Feed                      0.0259      0.001     34.290      0.000       0.024       0.027
# % Silica Feed                    0.0290      0.001     51.011      0.000       0.028       0.030
# Starch Flow                  -1.797e-05    8.2e-07    -21.920      0.000   -1.96e-05   -1.64e-05
# Amina Flow                       0.0007   1.45e-05     47.127      0.000       0.001       0.001
# Ore Pulp Flow                    0.0042      0.000     41.171      0.000       0.004       0.004
# Ore Pulp pH                      0.0465      0.003     18.319      0.000       0.042       0.052
# Ore Pulp Density                 0.1770      0.018      9.661      0.000       0.141       0.213
# Flotation Column 01 Air Flow    -0.0052      0.000    -49.256      0.000      -0.005      -0.005
# Flotation Column 02 Air Flow    -0.0014   6.14e-05    -23.233      0.000      -0.002      -0.001
# Flotation Column 03 Air Flow    -0.0009      0.000     -7.448      0.000      -0.001      -0.001
# Flotation Column 04 Air Flow     0.0020      0.000      4.420      0.000       0.001       0.003
# Flotation Column 05 Air Flow     0.0146      0.000     54.050      0.000       0.014       0.015
# Flotation Column 06 Air Flow -9.051e-05   6.13e-05     -1.476      0.140      -0.000    2.97e-05
# Flotation Column 07 Air Flow     0.0012    6.4e-05     19.125      0.000       0.001       0.001
# Flotation Column 01 Level       -0.0003   1.15e-05    -24.583      0.000      -0.000      -0.000
# Flotation Column 02 Level       -0.0002   1.06e-05    -14.713      0.000      -0.000      -0.000
# Flotation Column 03 Level    -8.155e-05   9.18e-06     -8.884      0.000   -9.95e-05   -6.36e-05
# Flotation Column 04 Level       -0.0001   1.39e-05     -9.514      0.000      -0.000      -0.000
# Flotation Column 05 Level       -0.0002   1.73e-05    -10.736      0.000      -0.000      -0.000
# Flotation Column 06 Level       -0.0002   1.33e-05    -16.414      0.000      -0.000      -0.000
# Flotation Column 07 Level        0.0002   1.64e-05     11.509      0.000       0.000       0.000
# % Iron Concentrate              -0.7877      0.001   -921.877      0.000      -0.789      -0.786
# ==============================================================================
# Omnibus:                     9552.469   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14205.960
# Skew:                           0.209   Prob(JB):                         0.00
# Kurtosis:                       3.698   Cond. No.                     7.24e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.24e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
residuals=model.resid
sns.distplot(residuals)

# %%
import scipy.stats as stats
stats.probplot(residuals,plot=plt)
plt.show()

# %% [markdown]
# ### Autocorrelation Check

# %%
import statsmodels.tsa.api as smt
acf=smt.graphics.plot_acf(residuals,lags=40)
acf.show()
# Out:
# C:\Users\pravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Multicollinearity Check

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
pd.DataFrame({'vif':vif},index=X.columns).T
# Out:
#      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  Ore Pulp Flow  \
# vif  2178.229333     101.709459     8.285713   66.267331    2050.570644
#
#      Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# vif   783.385154       1162.517251                    1113.77724
#
#      Flotation Column 02 Air Flow  Flotation Column 03 Air Flow  ...  \
# vif                    371.819081                   1360.240068  ...
#
#      Flotation Column 06 Air Flow  Flotation Column 07 Air Flow  \
# vif                     406.72177                    431.647431
#
#      Flotation Column 01 Level  Flotation Column 02 Level  \
# vif                  48.694746                  41.513635
#
#      Flotation Column 03 Level  Flotation Column 04 Level  \
# vif                   32.64072                   45.21573
#
#      Flotation Column 05 Level  Flotation Column 06 Level  \
# vif                   71.38788                  42.895211
#
#      Flotation Column 07 Level  % Iron Concentrate
# vif                  62.845861         3689.396944
#
# [1 rows x 22 columns]

# %%
from sklearn import metrics

# %% [markdown]
# ### 2.Linear Regression -ML

# %%
y=train['% Silica Concentrate']
X=train.drop(['% Silica Concentrate'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                        test_size=0.30, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train_pred=lr.predict(X_train)
print ("feature_importances:",lr.intercept_)
print ("n_coefficients:         ",lr.coef_)
# Out:
# feature_importances: 46.18661136652818
# n_coefficients:          [ 2.61852936e-02  2.91433665e-02 -1.71750033e-05  6.90463650e-04
#   4.20741752e-03  4.74046879e-02  1.79422295e-01 -5.24128587e-03
#  -1.45265940e-03 -7.79690312e-04  1.94300509e-03  1.43477605e-02
#  -6.02485759e-05  1.19416654e-03 -2.80567752e-04 -1.52038378e-04
#  -8.86344803e-05 -1.38945985e-04 -1.97619142e-04 -2.03616416e-04
#   1.89832585e-04 -7.86901623e-01]

# %%
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.6787714844528949
# L1 Mean absolute Error:  0.49213906613675146
# L2 Mean square Error:  0.40622343788010706
# L2 RMSE:  0.6373566018173085

# %%
y_test_pred=lr.predict(X_test)

# %%
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.6831168336650186
# L1 Mean absolute Error:  0.49126653676542265
# L2 Mean square Error:  0.40386608156328646
# L2 RMSE:  0.6355045881528208

# %% [markdown]
# ## 3. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### Changing max depth

# %%
train_accuracy=[]
test_accuracy=[]

for depth in range(5,20):
    dt_model=DecisionTreeRegressor(max_depth=depth,random_state=42)
    dt_model.fit(X_train,y_train)
    train_accuracy.append(dt_model.score(X_train,y_train))
    test_accuracy.append(dt_model.score(X_test,y_test))

# %%
frame=pd.DataFrame({'max_depth':range(5,20),'train_accuracy':train_accuracy,'test_accuracy':test_accuracy})
print(frame)
# Out:
#     max_depth  train_accuracy  test_accuracy
# 0           5        0.722489       0.725384
# 1           6        0.750020       0.751803
# 2           7        0.774981       0.776252
# 3           8        0.800064       0.800477
# 4           9        0.827885       0.828111
# 5          10        0.857924       0.856572
# 6          11        0.885482       0.882311
# 7          12        0.911283       0.907341
# 8          13        0.932899       0.928218
# 9          14        0.949638       0.943694
# 10         15        0.962082       0.955433
# 11         16        0.971825       0.964187
# 12         17        0.979965       0.972252
# 13         18        0.985962       0.977801
# 14         19        0.990482       0.982162

# %%
plt.figure(figsize=(13,6))
plt.plot(frame['max_depth'],frame['train_accuracy'],marker='o')
plt.plot(frame['max_depth'],frame['test_accuracy'],marker='o')
plt.xlabel('Depth of Tree')
plt.ylabel('Accuracy Performance')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
print ("feature_importances:",dtr.feature_importances_)
print ("Best params: \n        ",dtr.get_params)
print('n feature',dtr.n_features_)
print(dtr.n_outputs_)
# Out:
# feature_importances: [0.03583134 0.03878298 0.00887848 0.01829414 0.00620186 0.02721298
#  0.01680624 0.01762488 0.00435479 0.00425957 0.01261993 0.01118014
#  0.00474282 0.00168639 0.01112797 0.00827173 0.01879606 0.0019045
#  0.0069642  0.00466816 0.00392386 0.73586698]
# Best params:
#          <bound method BaseEstimator.get_params of DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')>
# n feature 22
# 1

# %%
y_train_pred=dtr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.9999999986666772
# L1 Mean absolute Error:  5.22583697297639e-06
# L2 Mean square Error:  1.686111085889226e-09
# L2 RMSE:  4.106228300873231e-05

# %%
y_test_pred=dtr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.9906292162583296
# L1 Mean absolute Error:  0.012160581093973452
# L2 Mean square Error:  0.011943019109209134
# L2 RMSE:  0.10928412102958569

# %% [markdown]
# ## 4. Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
print ("feature_importances:",rfr.feature_importances_)
print ("n_coefficients:         ",rfr.get_params)
print('n feature',rfr.n_features_)
print(rfr.n_outputs_)
# Out:
# feature_importances: [0.03680537 0.03893103 0.00925045 0.01828866 0.00626737 0.02634745
#  0.01538636 0.01839264 0.00563016 0.00439874 0.01421755 0.01064761
#  0.00472824 0.00200081 0.01137381 0.00845614 0.01887926 0.00268195
#  0.00669519 0.00480722 0.0034359  0.73237809]
# n_coefficients:          <bound method BaseEstimator.get_params of RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)>
# n feature 22
# 1

# %%
y_train_pred=rfr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# R2 of Train:  0.9996305739767505
# L1 Mean absolute Error:  0.006027372639132162
# L2 Mean square Error:  0.00046717368460026117
# L2 RMSE:  0.02161420099379714

# %%
y_test_pred=rfr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# R2 of Test:  0.9976148625298542
# L1 Mean absolute Error:  0.01571886900814239
# L2 Mean square Error:  0.0030398463105460634
# L2 RMSE:  0.055134801265136195

# %% [markdown]
# ## Considering Random Forest Regressor Base Model as the final model. Implementing the model in the test data set

# %%
test
# Out:
#         % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  Ore Pulp Flow  \
# 663081        57.80          10.71  1885.202000  524.179000     385.254000
# 284033        64.03           6.26  4097.670000  370.828000     406.774000
# 210448        52.61          20.24  3789.750000  430.187000     397.435000
# 209755        52.61          20.24   175.331966  274.168296     415.323250
# 469503        50.80          20.31  2405.740000  407.403000     401.522000
# ...             ...            ...          ...         ...            ...
# 422668        59.25           9.39  4122.610000  590.160000     404.395000
# 32461         61.38           8.40  2377.210000  537.993000     401.712000
# 315664        64.03           6.26  3384.350000  426.873000     398.621000
# 712418        54.14          14.69  2718.680000  526.397000     381.937667
# 177826        59.78           9.29  2356.140000  581.834000     399.666000
#
#         Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 663081     9.560970          1.725100                       299.715
# 284033     9.663950          1.623270                       299.583
# 210448     9.259250          1.592080                       250.316
# 209755     8.753679          1.521162                       249.410
# 469503     9.891430          1.706960                       300.147
# ...             ...               ...                           ...
# 422668     9.406390          1.721990                       299.773
# 32461      9.270330          1.733640                       198.933
# 315664     9.973300          1.738160                       302.725
# 712418     9.217810          1.703960                       297.470
# 177826    10.011400          1.781460                       299.590
#
#         Flotation Column 02 Air Flow  Flotation Column 03 Air Flow  ...  \
# 663081                       298.462                       301.685  ...
# 284033                       303.117                       299.210  ...
# 210448                       251.971                       249.427  ...
# 209755                       247.512                       249.803  ...
# 469503                       297.443                       298.828  ...
# ...                              ...                           ...  ...
# 422668                       298.112                       296.218  ...
# 32461                        197.174                       199.712  ...
# 315664                       255.742                       302.373  ...
# 712418                       304.367                       302.232  ...
# 177826                       300.839                       298.496  ...
#
#         Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# 663081                       305.070                 496.669000
# 284033                       301.183                 544.150000
# 210448                       300.245                 461.089000
# 209755                       297.217                 805.489398
# 469503                       299.540                 484.595000
# ...                              ...                        ...
# 422668                       301.231                 404.985000
# 32461                        253.225                 855.678772
# 315664                       297.890                 590.733000
# 712418                       305.895                 363.729000
# 177826                       303.204                 452.527000
#
#         Flotation Column 02 Level  Flotation Column 03 Level  \
# 663081                 526.044000                 416.630000
# 284033                 549.796000                 554.717000
# 210448                 458.032000                 388.418000
# 209755                 792.260602                 827.487572
# 469503                 510.760000                 503.809000
# ...                           ...                        ...
# 422668                 442.308000                 422.841000
# 32461                  814.493738                 886.288000
# 315664                 592.013000                 589.439000
# 712418                 615.971000                 401.459000
# 177826                 450.389000                 873.045338
#
#         Flotation Column 04 Level  Flotation Column 05 Level  \
# 663081                 295.819000                 387.954000
# 284033                 412.193000                 446.228000
# 210448                 334.271000                 332.731000
# 209755                 655.888161                 610.898941
# 469503                 514.369000                 508.241000
# ...                           ...                        ...
# 422668                 378.033000                 380.764000
# 32461                  563.049000                 560.053000
# 315664                 463.293000                 521.417000
# 712418                 333.594000                 349.656000
# 177826                 324.701000                 354.294000
#
#         Flotation Column 06 Level  Flotation Column 07 Level  \
# 663081                 439.394000                 378.813000
# 284033                 500.413000                 397.745000
# 210448                 341.183000                 369.438000
# 209755                 691.913959                 536.223639
# 469503                 445.536000                 449.678000
# ...                           ...                        ...
# 422668                 402.199000                 381.242000
# 32461                  622.843000                 573.897000
# 315664                 511.141000                 484.122000
# 712418                 297.433000                 321.551000
# 177826                 336.845000                 372.389000
#
#         % Iron Concentrate  % Silica Concentrate
# 663081           65.150000              1.230000
# 284033           66.310000              1.190000
# 210448           64.090000              4.150000
# 209755           62.870000              5.030000
# 469503           66.790000              1.250000
# ...                    ...                   ...
# 422668           65.630000              1.590000
# 32461            64.460000              4.920000
# 315664           65.700000              2.220000
# 712418           63.200000              2.730000
# 177826           62.085097              3.878073
#
# [220885 rows x 23 columns]

# %%
expected_output=train['% Silica Concentrate']
expected_input=train.drop(['% Silica Concentrate'],axis=1)

# %%
y_pred=rfr.predict(expected_input)

# %%
print('R2 of Output: ', metrics.r2_score(expected_output,y_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(expected_output,y_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(expected_output,y_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(expected_output,y_pred)))
# Out:
# R2 of Output:  0.9990225523407494
# L1 Mean absolute Error:  0.008934838473384908
# L2 Mean square Error:  0.001238979964853619
# L2 RMSE:  0.03519914721770428

# %% [markdown]
# ## Gradient Boosting

# %%
params = {
    'n_estimators': 80,
    'max_depth': 12,
    'learning_rate': 0.1,
    'criterion': 'mse'
    }

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(**params)

# %%
gbr.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-8524f4833dd0> in <module>
# ----> 1 gbr.fit(X_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in fit(self, X, y, sample_weight, monitor)
#    1535         n_stages = self._fit_stages(
#    1536             X, y, raw_predictions, sample_weight, self._rng, X_val, y_val,
# -> 1537             sample_weight_val, begin_at_stage, monitor, X_idx_sorted)
#    1538
#    1539         # change shape of arrays after fit (early-stopping or additional ests)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor, X_idx_sorted)
#    1592             raw_predictions = self._fit_stage(
#    1593                 i, X, y, raw_predictions, sample_weight, sample_mask,
# -> 1594                 random_state, X_idx_sorted, X_csc, X_csr)
#    1595
#    1596             # track deviance (= loss)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_idx_sorted, X_csc, X_csr)
#    1243             X = X_csr if X_csr is not None else X
#    1244             tree.fit(X, residual, sample_weight=sample_weight,
# -> 1245                      check_input=False, X_idx_sorted=X_idx_sorted)
#    1246
#    1247             # update tree leaves
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1223             sample_weight=sample_weight,
#    1224             check_input=check_input,
# -> 1225             X_idx_sorted=X_idx_sorted)
#    1226         return self
#    1227
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     365                                            min_impurity_split)
#     366
# --> 367         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     368
#     369         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
y_train_pred=gbr.predict(X_train)
print('R2 of Train: ', metrics.r2_score(y_train,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train,y_train_pred)))

# %%
y_test_pred=gbr.predict(X_test)
print('R2 of Test: ', metrics.r2_score(y_test,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))

# %% [markdown]
# ## Dimensionaly Reduction with PCA n=15

# %%
from sklearn.decomposition import PCA

# %%
# Dimensions reduction with Principal Components Analysis
pca = PCA(n_components=15)
pca.fit(X)
X_pca = pca.fit_transform(X)

# Creation of the different datasets for training and testing
X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(X_pca, y, test_size=0.8, random_state=42)

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(**params)

# %%
gbr.fit(X_train_pca,y_train_pca)

# %%
y_train_pred=gbr.predict(X_train_pca)
print('R2 of Train: ', metrics.r2_score(y_train_pca,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train_pca,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train_pca,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train_pca,y_train_pred)))

# %%
y_test_pred=gbr.predict(X_test_pca)
print('R2 of Test: ', metrics.r2_score(y_test_pca,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test_pca,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test_pca,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test_pca,y_test_pred)))

# %% [markdown]
# ### Random Forest Regressor

# %%
rfr_pca=RandomForestRegressor()

# %%
rfr_pca.fit(X_train_pca,y_train_pca)

# %%
print ("feature_importances:",rfr_pca.feature_importances_)
print ("n_coefficients:         ",rfr_pca.get_params)
print('n feature',rfr_pca.n_features_)
print(rfr_pca.n_outputs_)

# %%
y_train_pred=rfr_pca.predict(X_train_pca)
print('R2 of Train: ', metrics.r2_score(y_train_pca,y_train_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_train_pca,y_train_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_train_pca,y_train_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_train_pca,y_train_pred)))

# %%
y_test_pred=rfr_pca.predict(X_test_pca)
print('R2 of Test: ', metrics.r2_score(y_test_pca,y_test_pred))
print('L1 Mean absolute Error: ',metrics.mean_absolute_error(y_test_pca,y_test_pred))
print('L2 Mean square Error: ',metrics.mean_squared_error(y_test_pca,y_test_pred))
print('L2 RMSE: ',np.sqrt(metrics.mean_squared_error(y_test_pca,y_test_pred)))

# %%
del X_train_pca, X_test_pca, y_train_pca, y_test_pca,rfr_pca,gbr
